# %% [markdown]
# sample.ipynb의 함수를 참고해 호출해 분석하는 코드를 작성해보았습니다.
# GameAnalysis.py를 클라우드에 올려 작동하면 되지 않을까 싶습니다.

# %%
token = 'RGAPI-8a738c85-50b3-4ce6-a0ad-0b2fd69398e4'

# %% [markdown]
# # UserID

# %%
import requests

#유저 아이디로 상세정보 받아옴
def get_detail_user_from_id(user_id):
    url = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/' + user_id
    header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.118 Whale/2.11.126.23 Safari/537.36",
        "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "https://developer.riotgames.com",
        "X-Riot-Token": token
    }
    res = requests.get(url, headers = header)
    if res.status_code != 200:
        print("ERROR OCCURED", res.status_code)
    user_detail = json.loads(res.text)
    return (user_detail, res.status_code)

#encrypted id로 더 자세한 유저 정보 받아옴
def get_more_detail_user_from_enid(enid):
    url = 'https://kr.api.riotgames.com/lol/league/v4/entries/by-summoner/' + enid
    header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.118 Whale/2.11.126.23 Safari/537.36",
        "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "https://developer.riotgames.com",
        "X-Riot-Token": token
    }
    res = requests.get(url, headers = header)
    if res.status_code != 200:
        print("ERROR OCCURED", res.status_code)
    user_more_detail = json.loads(res.text)
    return (user_more_detail, res.status_code)


# get_puuid_from_id는 겹쳐서 일단 삭제

# %%
get_detail_user_from_id('올뮤트했다')[0]
# Out:
# {'id': '745_8bPjBEHd1I8YBOnTwAJXN9Be-saU1lw8SumvtECnZfI',
#  'accountId': '4LbYjp0U9ZbZlvRDof0vAYbD6V5DGBxQsMYnkTS-vGeepKMukYAZirfS',
#  'puuid': '7qh93BEwARilTztBJnXw5C_IomC3JMwq_TTsYsRrmvfnLSBKuSU-mRETl_rnD8Oz7WdTNjuUwGNa3w',
#  'name': '올뮤트했다',
#  'profileIconId': 4357,
#  'revisionDate': 1638056642000,
#  'summonerLevel': 63}

# %%
#브실골플다 유저 리스트 받아옴
def get_user_list_from_tier(tier, division, page):
    url = 'https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/'+tier+'/'+division+'?page=' + str(page)
    header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.118 Whale/2.11.126.23 Safari/537.36",
        "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "https://developer.riotgames.com",
        "X-Riot-Token": token
    }
    res = requests.get(url, headers=header)
    if res.status_code != 200:
        print("ERROR OCCURED", res.status_code)
    normal_user_list = json.loads(res.text)
    return (normal_user_list, res.status_code)


#챌,그마,마스터 유저받아옴
def get_cgmm_user(tier):
    url = 'https://kr.api.riotgames.com/lol/league/v4/' + tier + 'leagues/by-queue/RANKED_SOLO_5x5'
    header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.118 Whale/2.11.126.23 Safari/537.36",
        "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "https://developer.riotgames.com",
        "X-Riot-Token": token
    }
    
    res = requests.get(url, headers=header)
    if res.status_code != 200:
        print("ERROR OCCURED", res.status_code)
    user_list = json.loads(res.text)
    return (user_list, res.status_code)

# %% [markdown]
# # MatchList

# %%
#puuid count로 특정 유저의 게임 리스트 받아옴
def get_matches_from_puuid(puuid, count=20):
    url = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}%27/ids?start=0&count=' + str(count)
    header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.118 Whale/2.11.126.23 Safari/537.36",
        "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "https://developer.riotgames.com",
        "X-Riot-Token": token
    } 
    res = requests.get(url, headers=header)
    if res.status_code != 200:
        print("ERROR OCCURED", res.status_code)
    game_list = json.loads(res.text)
    return (game_list, res.status_code)

# %%
list = get_matches_from_puuid(get_detail_user_from_id('올뮤트했다')[0]['puuid'])[0]
list
# Out:
# ['KR_5594247935',
#  'KR_5464903618',
#  'KR_5464850976',
#  'KR_5457398352',
#  'KR_5443327712',
#  'KR_5443394140',
#  'KR_5442774537',
#  'KR_5442678501',
#  'KR_5441312591',
#  'KR_5441217952',
#  'KR_5441171228',
#  'KR_5441126881',
#  'KR_5440879145',
#  'KR_5439805457',
#  'KR_5437892564',
#  'KR_5437695318',
#  'KR_5437445953',
#  'KR_5436216976',
#  'KR_5436167164',
#  'KR_5436131622']

# %% [markdown]
# # MatchDetail

# %%
#게임 종합 정보 정도, 킬이랑 데미지, 아이템산거 등등
def get_match_detail_from_game_id(game_id):
    url = 'https://asia.api.riotgames.com/lol/match/v5/matches/' + game_id
    header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.118 Whale/2.11.126.23 Safari/537.36",
        "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "https://developer.riotgames.com",
        "X-Riot-Token": token
    } 
    res = requests.get(url, headers=header)
    if res.status_code != 200:
        print("ERROR OCCURED", res.status_code)
    game_info = json.loads(res.text)
    return (game_info, res.status_code)

#게임의 더욱 상세한 타임라인. 하나하나 다 기록되어 있는것같음
def get_match_timeline_from_game_id(game_id):
    url = 'https://asia.api.riotgames.com/lol/match/v5/matches/'+game_id+'/timeline'
    header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.118 Whale/2.11.126.23 Safari/537.36",
        "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "https://developer.riotgames.com",
        "X-Riot-Token": token
    }
    res = requests.get(url, headers=header)
    if res.status_code != 200:
        print("ERROR OCCURED", res.status_code)
    timeline = json.loads(res.text)
    return (timeline, res.status_code)

# %% [markdown]
# # 경기 결과분석

# %%
detail = get_match_detail_from_game_id(list[0])[0]['info']
detail
# Out:
# {'gameCreation': 1638083906000,
#  'gameDuration': 1507,
#  'gameEndTimestamp': 1638085441686,
#  'gameId': 5594247935,
#  'gameMode': 'CLASSIC',
#  'gameName': 'teambuilder-match-5594247935',
#  'gameStartTimestamp': 1638083933924,
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '11.23.409.111',
#  'mapId': 11,
#  'participants': [{'assists': 3,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'champExperience': 9943,
#    'champLevel': 12,
#    'championId': 236,
#    'championName': 'Lucian',
#    'championTransform': 0,
#    'consumablesPurchased': 4,
#    'damageDealtToBuildings': 109,
#    'damageDealtToObjectives': 109,
#    'damageDealtToTurrets': 109,
#    'damageSelfMitigated': 5201,
#    'deaths': 6,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 8040,
#    'goldSpent': 7750,
#    'individualPosition': 'TOP',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 6672,
#    'item1': 3153,
#    'item2': 0,
#    'item3': 3158,
#    'item4': 0,
#    'item5': 0,
#    'item6': 3340,
#    'itemsPurchased': 17,
#    'killingSprees': 0,
#    'kills': 5,
#    'lane': 'TOP',
#    'largestCriticalStrike': 305,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 765,
#    'magicDamageDealt': 3003,
#    'magicDamageDealtToChampions': 455,
#    'magicDamageTaken': 11106,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 1,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8112, 'var1': 734, 'var2': 0, 'var3': 0},
#        {'perk': 8139, 'var1': 671, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 9, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 942, 'var2': 4, 'var3': 0}],
#       'style': 8100},
#      {'description': 'subStyle',
#       'selections': [{'perk': 9111, 'var1': 357, 'var2': 160, 'var3': 0},
#        {'perk': 8014, 'var1': 282, 'var2': 0, 'var3': 0}],
#       'style': 8000}]},
#    'physicalDamageDealt': 63753,
#    'physicalDamageDealtToChampions': 8355,
#    'physicalDamageTaken': 3458,
#    'profileIcon': 4589,
#    'puuid': 'qVWqv7rwyHKfGLXeWOu3b2jmVSjldDZjGgjcBY1mVzsShkzvq4jJY9kj1J07q1QO7cAEhLKwFNehCg',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 49,
#    'spell2Casts': 23,
#    'spell3Casts': 19,
#    'spell4Casts': 8,
#    'summoner1Casts': 3,
#    'summoner1Id': 7,
#    'summoner2Casts': 2,
#    'summoner2Id': 4,
#    'summonerId': 'O-6-NcUf-wdZTHkjmgPDN479_ep2Ov1SNwrCWiDqj8x7B7U',
#    'summonerLevel': 40,
#    'summonerName': '빛날임씨',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'TOP',
#    'timeCCingOthers': 0,
#    'timePlayed': 1507,
#    'totalDamageDealt': 75137,
#    'totalDamageDealtToChampions': 9331,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 14683,
#    'totalHeal': 2451,
#    'totalHealsOnTeammates': 164,
#    'totalMinionsKilled': 108,
#    'totalTimeCCDealt': 0,
#    'totalTimeSpentDead': 215,
#    'totalUnitsHealed': 2,
#    'tripleKills': 0,
#    'trueDamageDealt': 8381,
#    'trueDamageDealtToChampions': 520,
#    'trueDamageTaken': 118,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 7,
#    'unrealKills': 0,
#    'visionScore': 11,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 7,
#    'win': False},
#   {'assists': 5,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'champExperience': 9279,
#    'champLevel': 12,
#    'championId': 19,
#    'championName': 'Warwick',
#    'championTransform': 0,
#    'consumablesPurchased': 2,
#    'damageDealtToBuildings': 0,
#    'damageDealtToObjectives': 17416,
#    'damageDealtToTurrets': 0,
#    'damageSelfMitigated': 38225,
#    'deaths': 13,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 1,
#    'dragonKills': 1,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 9788,
#    'goldSpent': 9525,
#    'individualPosition': 'JUNGLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 3047,
#    'item1': 3075,
#    'item2': 3068,
#    'item3': 3211,
#    'item4': 3067,
#    'item5': 0,
#    'item6': 3340,
#    'itemsPurchased': 11,
#    'killingSprees': 2,
#    'kills': 9,
#    'lane': 'JUNGLE',
#    'largestCriticalStrike': 16,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 325,
#    'magicDamageDealt': 43441,
#    'magicDamageDealtToChampions': 13939,
#    'magicDamageTaken': 25585,
#    'neutralMinionsKilled': 68,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 2,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8008, 'var1': 75, 'var2': 11, 'var3': 0},
#        {'perk': 9111, 'var1': 891, 'var2': 280, 'var3': 0},
#        {'perk': 9104, 'var1': 9, 'var2': 50, 'var3': 0},
#        {'perk': 8299, 'var1': 1085, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8234, 'var1': 7623, 'var2': 0, 'var3': 0},
#        {'perk': 8232, 'var1': 3, 'var2': 50, 'var3': 0}],
#       'style': 8200}]},
#    'physicalDamageDealt': 25089,
#    'physicalDamageDealtToChampions': 5043,
#    'physicalDamageTaken': 14569,
#    'profileIcon': 5076,
#    'puuid': 'YBdhMbsuCJOpjJIk1rG04eq0Y8JHIM1P4QCYZU_nT3UMCR42RHusqd8AzKona7IYuGEPlfea5uBzUg',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'NONE',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 86,
#    'spell2Casts': 6,
#    'spell3Casts': 31,
#    'spell4Casts': 8,
#    'summoner1Casts': 11,
#    'summoner1Id': 11,
#    'summoner2Casts': 4,
#    'summoner2Id': 4,
#    'summonerId': 'Ew3-8_43-ksM7OUejSM9LP0t86YJAl3CNV1VcbkJhC31BSsKqQMYHJ3ayQ',
#    'summonerLevel': 99,
#    'summonerName': '가위는 뭘까',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'JUNGLE',
#    'timeCCingOthers': 28,
#    'timePlayed': 1507,
#    'totalDamageDealt': 77377,
#    'totalDamageDealtToChampions': 19855,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 40726,
#    'totalHeal': 14994,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 33,
#    'totalTimeCCDealt': 251,
#    'totalTimeSpentDead': 373,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 8847,
#    'trueDamageDealtToChampions': 872,
#    'trueDamageTaken': 572,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 7,
#    'unrealKills': 0,
#    'visionScore': 6,
#    'visionWardsBoughtInGame': 1,
#    'wardsKilled': 0,
#    'wardsPlaced': 1,
#    'win': False},
#   {'assists': 3,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'champExperience': 8736,
#    'champLevel': 12,
#    'championId': 75,
#    'championName': 'Nasus',
#    'championTransform': 0,
#    'consumablesPurchased': 0,
#    'damageDealtToBuildings': 10185,
#    'damageDealtToObjectives': 10185,
#    'damageDealtToTurrets': 10185,
#    'damageSelfMitigated': 9385,
#    'deaths': 6,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': True,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 9010,
#    'goldSpent': 8333,
#    'individualPosition': 'JUNGLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 3078,
#    'item1': 6694,
#    'item2': 3133,
#    'item3': 2422,
#    'item4': 3057,
#    'item5': 0,
#    'item6': 3340,
#    'itemsPurchased': 15,
#    'killingSprees': 1,
#    'kills': 3,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 386,
#    'magicDamageDealt': 10035,
#    'magicDamageDealtToChampions': 1323,
#    'magicDamageTaken': 13699,
#    'neutralMinionsKilled': 2,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 3,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5002, 'offense': 5007},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8360, 'var1': 0, 'var2': 0, 'var3': 0},
#        {'perk': 8304, 'var1': 9, 'var2': 0, 'var3': 0},
#        {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#        {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#       'style': 8300},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8275, 'var1': 8, 'var2': 0, 'var3': 0},
#        {'perk': 8210, 'var1': 0, 'var2': 0, 'var3': 0}],
#       'style': 8200}]},
#    'physicalDamageDealt': 76426,
#    'physicalDamageDealtToChampions': 4407,
#    'physicalDamageTaken': 6140,
#    'profileIcon': 3455,
#    'puuid': 'TZWGlTAsoz0pywenGS8Wx7haUfT8pc-CrHT7z5TtWr07OFoHLsqh1UV5wJQOaeRCnHMxvUhgILJWNw',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'DUO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 127,
#    'spell2Casts': 19,
#    'spell3Casts': 39,
#    'spell4Casts': 7,
#    'summoner1Casts': 3,
#    'summoner1Id': 12,
#    'summoner2Casts': 5,
#    'summoner2Id': 4,
#    'summonerId': 'pEN8sSpOlReokqzMaWYtyEgCiou_XQEqme5vdtdG8gQkIxqg',
#    'summonerLevel': 128,
#    'summonerName': 'henrykimy',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'MIDDLE',
#    'timeCCingOthers': 15,
#    'timePlayed': 1507,
#    'totalDamageDealt': 86461,
#    'totalDamageDealtToChampions': 5731,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 19902,
#    'totalHeal': 1194,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 105,
#    'totalTimeCCDealt': 214,
#    'totalTimeSpentDead': 116,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 0,
#    'trueDamageDealtToChampions': 0,
#    'trueDamageTaken': 62,
#    'turretKills': 3,
#    'turretTakedowns': 3,
#    'turretsLost': 7,
#    'unrealKills': 0,
#    'visionScore': 12,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 8,
#    'win': False},
#   {'assists': 2,
#    'baronKills': 0,
#    'bountyLevel': 1,
#    'champExperience': 8604,
#    'champLevel': 12,
#    'championId': 36,
#    'championName': 'DrMundo',
#    'championTransform': 0,
#    'consumablesPurchased': 1,
#    'damageDealtToBuildings': 777,
#    'damageDealtToObjectives': 3234,
#    'damageDealtToTurrets': 777,
#    'damageSelfMitigated': 7513,
#    'deaths': 0,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'firstBloodAssist': True,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 7489,
#    'goldSpent': 6800,
#    'individualPosition': 'BOTTOM',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 2031,
#    'item1': 3211,
#    'item2': 3068,
#    'item3': 1054,
#    'item4': 3076,
#    'item5': 3009,
#    'item6': 3340,
#    'itemsPurchased': 12,
#    'killingSprees': 0,
#    'kills': 1,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 0,
#    'magicDamageDealt': 42565,
#    'magicDamageDealtToChampions': 1735,
#    'magicDamageTaken': 3284,
#    'neutralMinionsKilled': 48,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 4,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8229, 'var1': 401, 'var2': 0, 'var3': 0},
#        {'perk': 8224, 'var1': 56, 'var2': 0, 'var3': 0},
#        {'perk': 8233, 'var1': 12, 'var2': 50, 'var3': 0},
#        {'perk': 8237, 'var1': 214, 'var2': 0, 'var3': 0}],
#       'style': 8200},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8446, 'var1': 498, 'var2': 0, 'var3': 0},
#        {'perk': 8451, 'var1': 171, 'var2': 0, 'var3': 0}],
#       'style': 8400}]},
#    'physicalDamageDealt': 57369,
#    'physicalDamageDealtToChampions': 1292,
#    'physicalDamageTaken': 6218,
#    'profileIcon': 29,
#    'puuid': 'jJdbley4VpamDn1qyQu6KEttNmcTOu40oCqh0naV7XGxUqbWXc4J0pW9knzJ-qIk73_u5iurBx694w',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'DUO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 124,
#    'spell2Casts': 30,
#    'spell3Casts': 62,
#    'spell4Casts': 1,
#    'summoner1Casts': 1,
#    'summoner1Id': 4,
#    'summoner2Casts': 3,
#    'summoner2Id': 14,
#    'summonerId': 'gbpQrFscsuklYhW9AzHNUu3ozPN09KO2DGnLqs3KvEUrd9w',
#    'summonerLevel': 672,
#    'summonerName': '칼춤에 꽃놀이',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'BOTTOM',
#    'timeCCingOthers': 5,
#    'timePlayed': 1507,
#    'totalDamageDealt': 102902,
#    'totalDamageDealtToChampions': 3302,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 9503,
#    'totalHeal': 5937,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 95,
#    'totalTimeCCDealt': 210,
#    'totalTimeSpentDead': 0,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 2967,
#    'trueDamageDealtToChampions': 274,
#    'trueDamageTaken': 0,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 7,
#    'unrealKills': 0,
#    'visionScore': 3,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 3,
#    'win': False},
#   {'assists': 8,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'champExperience': 8989,
#    'champLevel': 12,
#    'championId': 99,
#    'championName': 'Lux',
#    'championTransform': 0,
#    'consumablesPurchased': 2,
#    'damageDealtToBuildings': 612,
#    'damageDealtToObjectives': 612,
#    'damageDealtToTurrets': 612,
#    'damageSelfMitigated': 6018,
#    'deaths': 11,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 1,
#    'dragonKills': 0,
#    'firstBloodAssist': True,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 7537,
#    'goldSpent': 6960,
#    'individualPosition': 'UTILITY',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 3853,
#    'item1': 2031,
#    'item2': 3020,
#    'item3': 6655,
#    'item4': 3108,
#    'item5': 3145,
#    'item6': 3340,
#    'itemsPurchased': 16,
#    'killingSprees': 1,
#    'kills': 3,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 265,
#    'magicDamageDealt': 32621,
#    'magicDamageDealtToChampions': 10805,
#    'magicDamageTaken': 13076,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 5,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8229, 'var1': 1259, 'var2': 0, 'var3': 0},
#        {'perk': 8226, 'var1': 250, 'var2': 349, 'var3': 0},
#        {'perk': 8210, 'var1': 5, 'var2': 0, 'var3': 0},
#        {'perk': 8236, 'var1': 24, 'var2': 0, 'var3': 0}],
#       'style': 8200},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#        {'perk': 8105, 'var1': 11, 'var2': 4, 'var3': 0}],
#       'style': 8100}]},
#    'physicalDamageDealt': 4028,
#    'physicalDamageDealtToChampions': 656,
#    'physicalDamageTaken': 5298,
#    'profileIcon': 23,
#    'puuid': '35jOwMpIRQikJLzJot0UvirktktiHdKeeoijAeJmnXdjOzgf4fyozTz97oVhgq1BVO8zY5AL76gyrA',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 45,
#    'spell2Casts': 9,
#    'spell3Casts': 78,
#    'spell4Casts': 8,
#    'summoner1Casts': 4,
#    'summoner1Id': 7,
#    'summoner2Casts': 4,
#    'summoner2Id': 4,
#    'summonerId': 'hRDi39_IZdIw95c2rPO6AbKVqK-rCRqNp7DFzpO2KFmcyfSv',
#    'summonerLevel': 85,
#    'summonerName': '루나라라랜드',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'UTILITY',
#    'timeCCingOthers': 52,
#    'timePlayed': 1507,
#    'totalDamageDealt': 36650,
#    'totalDamageDealtToChampions': 11461,
#    'totalDamageShieldedOnTeammates': 722,
#    'totalDamageTaken': 18495,
#    'totalHeal': 2007,
#    'totalHealsOnTeammates': 150,
#    'totalMinionsKilled': 27,
#    'totalTimeCCDealt': 181,
#    'totalTimeSpentDead': 220,
#    'totalUnitsHealed': 2,
#    'tripleKills': 0,
#    'trueDamageDealt': 0,
#    'trueDamageDealtToChampions': 0,
#    'trueDamageTaken': 120,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 7,
#    'unrealKills': 0,
#    'visionScore': 9,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 1,
#    'wardsPlaced': 5,
#    'win': False},
#   {'assists': 6,
#    'baronKills': 0,
#    'bountyLevel': 3,
#    'champExperience': 12193,
#    'champLevel': 14,
#    'championId': 517,
#    'championName': 'Sylas',
#    'championTransform': 0,
#    'consumablesPurchased': 4,
#    'damageDealtToBuildings': 4720,
#    'damageDealtToObjectives': 4720,
#    'damageDealtToTurrets': 4720,
#    'damageSelfMitigated': 16512,
#    'deaths': 6,
#    'detectorWardsPlaced': 2,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 10399,
#    'goldSpent': 8910,
#    'individualPosition': 'TOP',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 3158,
#    'item1': 3157,
#    'item2': 6656,
#    'item3': 1056,
#    'item4': 3108,
#    'item5': 3113,
#    'item6': 3364,
#    'itemsPurchased': 20,
#    'killingSprees': 3,
#    'kills': 10,
#    'lane': 'TOP',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 555,
#    'magicDamageDealt': 78551,
#    'magicDamageDealtToChampions': 22246,
#    'magicDamageTaken': 8799,
#    'neutralMinionsKilled': 8,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 6,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8010, 'var1': 446, 'var2': 0, 'var3': 0},
#        {'perk': 8009, 'var1': 4029, 'var2': 0, 'var3': 0},
#        {'perk': 9105, 'var1': 17, 'var2': 30, 'var3': 0},
#        {'perk': 8299, 'var1': 1383, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#        {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 7753,
#    'physicalDamageDealtToChampions': 865,
#    'physicalDamageTaken': 16925,
#    'profileIcon': 4779,
#    'puuid': 'pVJz-4Se8YoPjkHWbDAkN10vcIkcsWYk07MbqRVDAXsih9jSh8z6rc32cSefTR4qLVCJYaFqrTicjw',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 54,
#    'spell2Casts': 68,
#    'spell3Casts': 113,
#    'spell4Casts': 16,
#    'summoner1Casts': 3,
#    'summoner1Id': 12,
#    'summoner2Casts': 4,
#    'summoner2Id': 4,
#    'summonerId': 'r0Rx-yi8pGriCm_npws4E_yYOfnJ7NTII3nZoyUaqQooEFY',
#    'summonerLevel': 163,
#    'summonerName': '거노아좋띠',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'TOP',
#    'timeCCingOthers': 31,
#    'timePlayed': 1507,
#    'totalDamageDealt': 86305,
#    'totalDamageDealtToChampions': 23112,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 26375,
#    'totalHeal': 9232,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 102,
#    'totalTimeCCDealt': 247,
#    'totalTimeSpentDead': 204,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 0,
#    'trueDamageDealtToChampions': 0,
#    'trueDamageTaken': 650,
#    'turretKills': 2,
#    'turretTakedowns': 4,
#    'turretsLost': 4,
#    'unrealKills': 0,
#    'visionScore': 17,
#    'visionWardsBoughtInGame': 2,
#    'wardsKilled': 0,
#    'wardsPlaced': 4,
#    'win': True},
#   {'assists': 7,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'champExperience': 8155,
#    'champLevel': 11,
#    'championId': 102,
#    'championName': 'Shyvana',
#    'championTransform': 0,
#    'consumablesPurchased': 2,
#    'damageDealtToBuildings': 318,
#    'damageDealtToObjectives': 15531,
#    'damageDealtToTurrets': 318,
#    'damageSelfMitigated': 10252,
#    'deaths': 7,
#    'detectorWardsPlaced': 2,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 6937,
#    'goldSpent': 6470,
#    'individualPosition': 'JUNGLE',
#    'inhibitorKills': 1,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 3115,
#    'item1': 2031,
#    'item2': 3020,
#    'item3': 1026,
#    'item4': 1052,
#    'item5': 1052,
#    'item6': 3364,
#    'itemsPurchased': 15,
#    'killingSprees': 1,
#    'kills': 4,
#    'lane': 'JUNGLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 446,
#    'magicDamageDealt': 40754,
#    'magicDamageDealtToChampions': 5862,
#    'magicDamageTaken': 5223,
#    'neutralMinionsKilled': 58,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 7,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8128, 'var1': 641, 'var2': 13, 'var3': 0},
#        {'perk': 8143, 'var1': 177, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 986, 'var2': 4, 'var3': 0}],
#       'style': 8100},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8210, 'var1': 9, 'var2': 0, 'var3': 0},
#        {'perk': 8236, 'var1': 24, 'var2': 0, 'var3': 0}],
#       'style': 8200}]},
#    'physicalDamageDealt': 15928,
#    'physicalDamageDealtToChampions': 1208,
#    'physicalDamageTaken': 13174,
#    'profileIcon': 4357,
#    'puuid': '7qh93BEwARilTztBJnXw5C_IomC3JMwq_TTsYsRrmvfnLSBKuSU-mRETl_rnD8Oz7WdTNjuUwGNa3w',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'NONE',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 40,
#    'spell2Casts': 48,
#    'spell3Casts': 46,
#    'spell4Casts': 5,
#    'summoner1Casts': 3,
#    'summoner1Id': 4,
#    'summoner2Casts': 12,
#    'summoner2Id': 11,
#    'summonerId': '745_8bPjBEHd1I8YBOnTwAJXN9Be-saU1lw8SumvtECnZfI',
#    'summonerLevel': 63,
#    'summonerName': '올뮤트했다',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'JUNGLE',
#    'timeCCingOthers': 0,
#    'timePlayed': 1507,
#    'totalDamageDealt': 68734,
#    'totalDamageDealtToChampions': 7279,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 18555,
#    'totalHeal': 3939,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 1,
#    'totalTimeCCDealt': 45,
#    'totalTimeSpentDead': 137,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 12050,
#    'trueDamageDealtToChampions': 208,
#    'trueDamageTaken': 157,
#    'turretKills': 1,
#    'turretTakedowns': 2,
#    'turretsLost': 4,
#    'unrealKills': 0,
#    'visionScore': 12,
#    'visionWardsBoughtInGame': 2,
#    'wardsKilled': 1,
#    'wardsPlaced': 2,
#    'win': True},
#   {'assists': 12,
#    'baronKills': 0,
#    'bountyLevel': 5,
#    'champExperience': 12438,
#    'champLevel': 14,
#    'championId': 101,
#    'championName': 'Xerath',
#    'championTransform': 0,
#    'consumablesPurchased': 2,
#    'damageDealtToBuildings': 1941,
#    'damageDealtToObjectives': 2136,
#    'damageDealtToTurrets': 1941,
#    'damageSelfMitigated': 1814,
#    'deaths': 3,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 8369,
#    'goldSpent': 6285,
#    'individualPosition': 'MIDDLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 1056,
#    'item1': 3020,
#    'item2': 6655,
#    'item3': 3145,
#    'item4': 1052,
#    'item5': 0,
#    'item6': 3340,
#    'itemsPurchased': 14,
#    'killingSprees': 1,
#    'kills': 5,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 5,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 885,
#    'magicDamageDealt': 79837,
#    'magicDamageDealtToChampions': 13904,
#    'magicDamageTaken': 3140,
#    'neutralMinionsKilled': 2,
#    'nexusKills': 1,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 8,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8229, 'var1': 1127, 'var2': 0, 'var3': 0},
#        {'perk': 8226, 'var1': 250, 'var2': 936, 'var3': 0},
#        {'perk': 8210, 'var1': 15, 'var2': 0, 'var3': 0},
#        {'perk': 8237, 'var1': 514, 'var2': 0, 'var3': 0}],
#       'style': 8200},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#        {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 5992,
#    'physicalDamageDealtToChampions': 262,
#    'physicalDamageTaken': 2872,
#    'profileIcon': 26,
#    'puuid': 'c6B3UUueay0dctqC8P5Ta4Luj2aFBYfxvZuEAYxrmGSwqHRI1eL5n04ElL8c7avxZMOCJlR0sXvUng',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 83,
#    'spell2Casts': 61,
#    'spell3Casts': 23,
#    'spell4Casts': 22,
#    'summoner1Casts': 3,
#    'summoner1Id': 4,
#    'summoner2Casts': 4,
#    'summoner2Id': 14,
#    'summonerId': 'PqVSE4jFJVXfN4BBhdnw-Cs7D3b67KqV3qHWpveA4w-um2g',
#    'summonerLevel': 47,
#    'summonerName': '봐줘 본캐야',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'MIDDLE',
#    'timeCCingOthers': 21,
#    'timePlayed': 1507,
#    'totalDamageDealt': 90054,
#    'totalDamageDealtToChampions': 14697,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 6112,
#    'totalHeal': 438,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 99,
#    'totalTimeCCDealt': 246,
#    'totalTimeSpentDead': 39,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 4225,
#    'trueDamageDealtToChampions': 530,
#    'trueDamageTaken': 100,
#    'turretKills': 2,
#    'turretTakedowns': 3,
#    'turretsLost': 4,
#    'unrealKills': 0,
#    'visionScore': 5,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 3,
#    'win': True},
#   {'assists': 14,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'champExperience': 12161,
#    'champLevel': 14,
#    'championId': 157,
#    'championName': 'Yasuo',
#    'championTransform': 0,
#    'consumablesPurchased': 1,
#    'damageDealtToBuildings': 4174,
#    'damageDealtToObjectives': 15850,
#    'damageDealtToTurrets': 4174,
#    'damageSelfMitigated': 23316,
#    'deaths': 5,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 0,
#    'dragonKills': 1,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': True,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 12207,
#    'goldSpent': 12200,
#    'individualPosition': 'BOTTOM',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 6673,
#    'item1': 3072,
#    'item2': 3033,
#    'item3': 3006,
#    'item4': 1038,
#    'item5': 0,
#    'item6': 3340,
#    'itemsPurchased': 16,
#    'killingSprees': 2,
#    'kills': 7,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 493,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 487,
#    'magicDamageDealt': 8996,
#    'magicDamageDealtToChampions': 1096,
#    'magicDamageTaken': 7668,
#    'neutralMinionsKilled': 14,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 9,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 3013, 'var2': 3162, 'var3': 0},
#        {'perk': 9111, 'var1': 786, 'var2': 420, 'var3': 0},
#        {'perk': 9104, 'var1': 12, 'var2': 10, 'var3': 0},
#        {'perk': 8299, 'var1': 362, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8473, 'var1': 744, 'var2': 0, 'var3': 0},
#        {'perk': 8453, 'var1': 1425, 'var2': 617, 'var3': 0}],
#       'style': 8400}]},
#    'physicalDamageDealt': 141293,
#    'physicalDamageDealtToChampions': 12940,
#    'physicalDamageTaken': 14061,
#    'profileIcon': 3154,
#    'puuid': 'z1U2_HaWAWQ6IQCINQoxhN3jyY7PuPOElRlxmfe0WpsXys4y5qZsdEO3cyJuewTTK597nr-YWHqhdQ',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'CARRY',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 232,
#    'spell2Casts': 26,
#    'spell3Casts': 110,
#    'spell4Casts': 6,
#    'summoner1Casts': 4,
#    'summoner1Id': 4,
#    'summoner2Casts': 5,
#    'summoner2Id': 7,
#    'summonerId': 'TBiAiuh4cCg9q-B_S5kHuqpCgkdCpgZ630tASk2yHf9c3SqwL06nay--lg',
#    'summonerLevel': 64,
#    'summonerName': '탑치노',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'BOTTOM',
#    'timeCCingOthers': 21,
#    'timePlayed': 1507,
#    'totalDamageDealt': 152895,
#    'totalDamageDealtToChampions': 14036,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 24107,
#    'totalHeal': 5509,
#    'totalHealsOnTeammates': 935,
#    'totalMinionsKilled': 178,
#    'totalTimeCCDealt': 93,
#    'totalTimeSpentDead': 139,
#    'totalUnitsHealed': 4,
#    'tripleKills': 0,
#    'trueDamageDealt': 2605,
#    'trueDamageDealtToChampions': 0,
#    'trueDamageTaken': 2377,
#    'turretKills': 1,
#    'turretTakedowns': 4,
#    'turretsLost': 4,
#    'unrealKills': 0,
#    'visionScore': 11,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 0,
#    'wardsPlaced': 6,
#    'win': True},
#   {'assists': 6,
#    'baronKills': 0,
#    'bountyLevel': 10,
#    'champExperience': 10577,
#    'champLevel': 13,
#    'championId': 63,
#    'championName': 'Brand',
#    'championTransform': 0,
#    'consumablesPurchased': 3,
#    'damageDealtToBuildings': 2591,
#    'damageDealtToObjectives': 8305,
#    'damageDealtToTurrets': 2591,
#    'damageSelfMitigated': 4192,
#    'deaths': 0,
#    'detectorWardsPlaced': 1,
#    'doubleKills': 1,
#    'dragonKills': 1,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': True,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 11569,
#    'goldSpent': 10175,
#    'individualPosition': 'UTILITY',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 3157,
#    'item1': 3916,
#    'item2': 3853,
#    'item3': 6653,
#    'item4': 3041,
#    'item5': 3020,
#    'item6': 3364,
#    'itemsPurchased': 18,
#    'killingSprees': 1,
#    'kills': 10,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 10,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 0,
#    'magicDamageDealt': 80488,
#    'magicDamageDealtToChampions': 22254,
#    'magicDamageTaken': 5706,
#    'neutralMinionsKilled': 28,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 10,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5007},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8128, 'var1': 1840, 'var2': 23, 'var3': 0},
#        {'perk': 8139, 'var1': 1011, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 1174, 'var2': 4, 'var3': 0}],
#       'style': 8100},
#      {'description': 'subStyle',
#       'selections': [{'perk': 9111, 'var1': 789, 'var2': 320, 'var3': 0},
#        {'perk': 8014, 'var1': 754, 'var2': 0, 'var3': 0}],
#       'style': 8000}]},
#    'physicalDamageDealt': 4666,
#    'physicalDamageDealtToChampions': 1036,
#    'physicalDamageTaken': 4096,
#    'profileIcon': 4763,
#    'puuid': 'Tdu7l_UaZGB6-jypNp0wt5jPjSNJkUHZRB-cjxR2873FEkOu1xqdmNoNCGaeomDaDmFS806MIsQ5fw',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 47,
#    'spell2Casts': 83,
#    'spell3Casts': 35,
#    'spell4Casts': 7,
#    'summoner1Casts': 4,
#    'summoner1Id': 4,
#    'summoner2Casts': 1,
#    'summoner2Id': 21,
#    'summonerId': 'VmDwDl0YNhvu66eS7pNOebshyvCGzKTYxdk65QOCmrmwTs4',
#    'summonerLevel': 231,
#    'summonerName': '불금엔 치킨이닭',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'UTILITY',
#    'timeCCingOthers': 21,
#    'timePlayed': 1507,
#    'totalDamageDealt': 85633,
#    'totalDamageDealtToChampions': 23424,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 10185,
#    'totalHeal': 1647,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 49,
#    'totalTimeCCDealt': 50,
#    'totalTimeSpentDead': 0,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 478,
#    'trueDamageDealtToChampions': 134,
#    'trueDamageTaken': 381,
#    'turretKills': 1,
#    'turretTakedowns': 1,
#    'turretsLost': 4,
#    'unrealKills': 0,
#    'visionScore': 47,
#    'visionWardsBoughtInGame': 1,
#    'wardsKilled': 0,
#    'wardsPlaced': 16,
#    'win': True}],
#  'platformId': 'KR',
#  'queueId': 420,
#  'teams': [{'bans': [{'championId': 122, 'pickTurn': 1},
#     {'championId': 2, 'pickTurn': 2},
#     {'championId': 35, 'pickTurn': 3},
#     {'championId': 18, 'pickTurn': 4},
#     {'championId': 223, 'pickTurn': 5}],
#    'objectives': {'baron': {'first': False, 'kills': 0},
#     'champion': {'first': True, 'kills': 21},
#     'dragon': {'first': True, 'kills': 1},
#     'inhibitor': {'first': False, 'kills': 0},
#     'riftHerald': {'first': True, 'kills': 1},
#     'tower': {'first': False, 'kills': 4}},
#    'teamId': 100,
#    'win': False},
#   {'bans': [{'championId': 11, 'pickTurn': 6},
#     {'championId': 154, 'pickTurn': 7},
#     {'championId': 498, 'pickTurn': 8},
#     {'championId': -1, 'pickTurn': 9},
#     {'championId': 360, 'pickTurn': 10}],
#    'objectives': {'baron': {'first': False, 'kills': 0},
#     'champion': {'first': False, 'kills': 36},
#     'dragon': {'first': False, 'kills': 2},
#     'inhibitor': {'first': True, 'kills': 1},
#     'riftHerald': {'first': False, 'kills': 1},
#     'tower': {'first': True, 'kills': 7}},
#    'teamId': 200,
#    'win': True}],
#  'tournamentCode': ''}

# %%
import json
import pandas as pd
from pandas import json_normalize

df1 = json_normalize(detail)
df1
# Out:
#     gameCreation  gameDuration  ...                                              teams  tournamentCode
# 0  1638083906000          1507  ...  [{'bans': [{'championId': 122, 'pickTurn': 1},...
#
# [1 rows x 15 columns]

# %%
json_normalize(df1['participants'])
# Out:
#                                                    0  ...                                                  9
# 0  {'assists': 3, 'baronKills': 0, 'bountyLevel':...  ...  {'assists': 6, 'baronKills': 0, 'bountyLevel':...
#
# [1 rows x 10 columns]

# %% [markdown]
# # 경기 양상분석

# %%
timeline = get_match_timeline_from_game_id(list[0])[0]['info']
timeline
# Out:
# {'frameInterval': 60000,
#  'frames': [{'events': [{'realTimestamp': 1638083933774,
#      'timestamp': 0,
#      'type': 'PAUSE_END'}],
#    'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 28,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 25,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 571,
#       'healthMax': 571,
#       'healthRegen': 0,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 30,
#       'movementSpeed': 335,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 348,
#       'powerMax': 348,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 500,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 1,
#      'position': {'x': 554, 'y': 581},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '2': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 33,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 25,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 550,
#       'healthMax': 550,
#       'healthRegen': 0,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 335,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 280,
#       'powerMax': 280,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 500,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 2,
#      'position': {'x': 557, 'y': 345},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '3': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 34,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 25,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 561,
#       'healthMax': 561,
#       'healthRegen': 0,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 350,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 326,
#       'powerMax': 326,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 500,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 3,
#      'position': {'x': 335, 'y': 269},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '4': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 32,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 25,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 583,
#       'healthMax': 583,
#       'healthRegen': 0,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 345,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 0,
#       'powerMax': 0,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 500,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 4,
#      'position': {'x': 194, 'y': 457},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '5': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 19,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 25,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 490,
#       'healthMax': 490,
#       'healthRegen': 0,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 30,
#       'movementSpeed': 330,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 480,
#       'powerMax': 480,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 500,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 5,
#      'position': {'x': 329, 'y': 650},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '6': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 27,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 25,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 525,
#       'healthMax': 525,
#       'healthRegen': 0,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 340,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 310,
#       'powerMax': 310,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 500,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 6,
#      'position': {'x': 14180, 'y': 14271},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '7': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 38,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 25,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 595,
#       'healthMax': 595,
#       'healthRegen': 0,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 350,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 0,
#       'powerMax': 100,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 500,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 7,
#      'position': {'x': 14176, 'y': 14506},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '8': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 22,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 25,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 526,
#       'healthMax': 526,
#       'healthRegen': 0,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 30,
#       'movementSpeed': 340,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 459,
#       'powerMax': 459,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 500,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 8,
#      'position': {'x': 14398, 'y': 14582},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '9': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 30,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 25,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 490,
#       'healthMax': 490,
#       'healthRegen': 0,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 345,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 115,
#       'powerMax': 115,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 500,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 9,
#      'position': {'x': 14539, 'y': 14394},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '10': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 22,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 25,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 520,
#       'healthMax': 520,
#       'healthRegen': 0,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 30,
#       'movementSpeed': 340,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 469,
#       'powerMax': 469,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 500,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 10,
#      'position': {'x': 14404, 'y': 14201},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0}},
#    'timestamp': 0},
#   {'events': [{'levelUpType': 'NORMAL',
#      'participantId': 5,
#      'skillSlot': 1,
#      'timestamp': 3922,
#      'type': 'SKILL_LEVEL_UP'},
#     {'levelUpType': 'NORMAL',
#      'participantId': 1,
#      'skillSlot': 1,
#      'timestamp': 4154,
#      'type': 'SKILL_LEVEL_UP'},
#     {'itemId': 3850,
#      'participantId': 5,
#      'timestamp': 5479,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 5,
#      'timestamp': 5479,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 5,
#      'timestamp': 5479,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 1054,
#      'participantId': 4,
#      'timestamp': 8253,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 4,
#      'timestamp': 8253,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 1056,
#      'participantId': 8,
#      'timestamp': 8286,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 8,
#      'timestamp': 8286,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 8,
#      'timestamp': 8286,
#      'type': 'ITEM_PURCHASED'},
#     {'levelUpType': 'NORMAL',
#      'participantId': 10,
#      'skillSlot': 2,
#      'timestamp': 8353,
#      'type': 'SKILL_LEVEL_UP'},
#     {'levelUpType': 'NORMAL',
#      'participantId': 2,
#      'skillSlot': 1,
#      'timestamp': 8518,
#      'type': 'SKILL_LEVEL_UP'},
#     {'itemId': 1036,
#      'participantId': 1,
#      'timestamp': 10037,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 3850,
#      'participantId': 10,
#      'timestamp': 10103,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 10,
#      'timestamp': 10103,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 10,
#      'timestamp': 10103,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 1039,
#      'participantId': 7,
#      'timestamp': 10533,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 1054,
#      'participantId': 9,
#      'timestamp': 10632,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 9,
#      'timestamp': 10632,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 2,
#      'timestamp': 10698,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 3340,
#      'participantId': 10,
#      'timestamp': 10830,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2055,
#      'participantId': 2,
#      'timestamp': 11391,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 1035,
#      'participantId': 2,
#      'timestamp': 12283,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2031,
#      'participantId': 7,
#      'timestamp': 12878,
#      'type': 'ITEM_PURCHASED'},
#     {'levelUpType': 'NORMAL',
#      'participantId': 4,
#      'skillSlot': 1,
#      'timestamp': 13539,
#      'type': 'SKILL_LEVEL_UP'},
#     {'itemId': 2003,
#      'participantId': 1,
#      'timestamp': 13705,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 1,
#      'timestamp': 14134,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 1,
#      'timestamp': 14365,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 3364,
#      'participantId': 7,
#      'timestamp': 18528,
#      'type': 'ITEM_PURCHASED'},
#     {'levelUpType': 'NORMAL',
#      'participantId': 8,
#      'skillSlot': 2,
#      'timestamp': 20907,
#      'type': 'SKILL_LEVEL_UP'},
#     {'itemId': 1042,
#      'participantId': 3,
#      'timestamp': 34780,
#      'type': 'ITEM_PURCHASED'},
#     {'levelUpType': 'NORMAL',
#      'participantId': 3,
#      'skillSlot': 1,
#      'timestamp': 35606,
#      'type': 'SKILL_LEVEL_UP'},
#     {'creatorId': 5,
#      'timestamp': 42279,
#      'type': 'WARD_PLACED',
#      'wardType': 'YELLOW_TRINKET'},
#     {'levelUpType': 'NORMAL',
#      'participantId': 7,
#      'skillSlot': 3,
#      'timestamp': 49381,
#      'type': 'SKILL_LEVEL_UP'},
#     {'levelUpType': 'NORMAL',
#      'participantId': 9,
#      'skillSlot': 1,
#      'timestamp': 52189,
#      'type': 'SKILL_LEVEL_UP'},
#     {'itemId': 1056,
#      'participantId': 6,
#      'timestamp': 55921,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 6,
#      'timestamp': 55921,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 2003,
#      'participantId': 6,
#      'timestamp': 55921,
#      'type': 'ITEM_PURCHASED'},
#     {'itemId': 3340,
#      'participantId': 6,
#      'timestamp': 56780,
#      'type': 'ITEM_PURCHASED'}],
#    'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 34,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 77,
#       'attackSpeed': 110,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 571,
#       'healthMax': 571,
#       'healthRegen': 7,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 30,
#       'movementSpeed': 335,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 348,
#       'powerMax': 348,
#       'powerRegen': 16,
#       'spellVamp': 0},
#      'currentGold': 0,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 1,
#      'position': {'x': 1324, 'y': 10437},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '2': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 39,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 70,
#       'attackSpeed': 113,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 550,
#       'healthMax': 550,
#       'healthRegen': 8,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 338,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 280,
#       'powerMax': 280,
#       'powerRegen': 14,
#       'spellVamp': 0},
#      'currentGold': 25,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 2,
#      'position': {'x': 10173, 'y': 7147},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '3': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 46,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 67,
#       'attackSpeed': 112,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 561,
#       'healthMax': 561,
#       'healthRegen': 18,
#       'lifesteal': 10,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 350,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 326,
#       'powerMax': 326,
#       'powerRegen': 14,
#       'spellVamp': 0},
#      'currentGold': 200,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 3,
#      'position': {'x': 10045, 'y': 6056},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '4': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 32,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 73,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 678,
#       'healthMax': 678,
#       'healthRegen': 41,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 345,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 0,
#       'powerMax': 0,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 0,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 4,
#      'position': {'x': 10439, 'y': 7435},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '5': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 26,
#       'armor': 19,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 54,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 464,
#       'healthMax': 515,
#       'healthRegen': 11,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 30,
#       'movementSpeed': 335,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 480,
#       'powerMax': 480,
#       'powerRegen': 24,
#       'spellVamp': 0},
#      'currentGold': 0,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 77,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 77,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 20,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 5,
#      'position': {'x': 9826, 'y': 6220},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '6': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 33,
#       'armor': 33,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 61,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 5,
#       'cooldownReduction': 0,
#       'health': 595,
#       'healthMax': 595,
#       'healthRegen': 18,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 697,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 310,
#       'powerMax': 310,
#       'powerRegen': 16,
#       'spellVamp': 0},
#      'currentGold': 0,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 6,
#      'position': {'x': 12218, 'y': 14152},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '7': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 49,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 71,
#       'attackSpeed': 110,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 595,
#       'healthMax': 595,
#       'healthRegen': 17,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 37,
#       'movementSpeed': 350,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 0,
#       'powerMax': 100,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 0,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 7,
#      'position': {'x': 11718, 'y': 7301},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '8': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 33,
#       'armor': 28,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 55,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 596,
#       'healthMax': 596,
#       'healthRegen': 11,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 30,
#       'movementSpeed': 340,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 459,
#       'powerMax': 459,
#       'powerRegen': 16,
#       'spellVamp': 0},
#      'currentGold': 0,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 8,
#      'position': {'x': 11436, 'y': 7910},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '9': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 30,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 65,
#       'attackSpeed': 113,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 570,
#       'healthMax': 570,
#       'healthRegen': 25,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 40,
#       'movementSpeed': 345,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 120,
#       'powerMax': 120,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 0,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 0,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 9,
#      'position': {'x': 11282, 'y': 6132},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 500,
#      'xp': 0},
#     '10': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 17,
#       'armor': 22,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 57,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 545,
#       'healthMax': 545,
#       'healthRegen': 11,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 30,
#       'movementSpeed': 340,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 469,
#       'powerMax': 469,
#       'powerRegen': 32,
#       'spellVamp': 0},
#      'currentGold': 40,
#      'damageStats': {'magicDamageDone': 77,
#       'magicDamageDoneToChampions': 77,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 0,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 77,
#       'totalDamageDoneToChampions': 77,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 20,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 10,
#      'position': {'x': 9912, 'y': 7924},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 540,
#      'xp': 0}},
#    'timestamp': 60017},
#   {'events': [{'creatorId': 3,
#      'timestamp': 66204,
#      'type': 'WARD_PLACED',
#      'wardType': 'YELLOW_TRINKET'},
#     {'creatorId': 8,
#      'timestamp': 73306,
#      'type': 'WARD_PLACED',
#      'wardType': 'YELLOW_TRINKET'},
#     {'assistingParticipantIds': [4, 5],
#      'bounty': 400,
#      'killStreakLength': 0,
#      'killerId': 3,
#      'position': {'x': 12089, 'y': 8292},
#      'timestamp': 78756,
#      'type': 'CHAMPION_KILL',
#      'victimDamageReceived': [{'basic': False,
#        'magicDamage': 73,
#        'name': 'Lux',
#        'participantId': 5,
#        'physicalDamage': 0,
#        'spellName': 'luxlightbinding',
#        'spellSlot': 0,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 19,
#        'name': 'Lux',
#        'participantId': 5,
#        'physicalDamage': 0,
#        'spellName': 'luxilluminationpassive',
#        'spellSlot': 63,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 27,
#        'name': 'Lux',
#        'participantId': 5,
#        'physicalDamage': 0,
#        'spellName': '',
#        'spellSlot': -1,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'Lux',
#        'participantId': 5,
#        'physicalDamage': 42,
#        'spellName': 'luxbasicattack',
#        'spellSlot': 64,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'Lux',
#        'participantId': 5,
#        'physicalDamage': 84,
#        'spellName': 'luxbasicattack2',
#        'spellSlot': 65,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 80,
#        'name': 'DrMundo',
#        'participantId': 4,
#        'physicalDamage': 0,
#        'spellName': 'drmundoq',
#        'spellSlot': 0,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 11,
#        'name': 'DrMundo',
#        'participantId': 4,
#        'physicalDamage': 26,
#        'spellName': '',
#        'spellSlot': -1,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'DrMundo',
#        'participantId': 4,
#        'physicalDamage': 57,
#        'spellName': 'drmundobasicattack2',
#        'spellSlot': 65,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 0,
#        'name': 'DrMundo',
#        'participantId': 4,
#        'physicalDamage': 0,
#        'spellName': 'summonerdot',
#        'spellSlot': 5,
#        'trueDamage': 28,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 0,
#        'name': 'Nasus',
#        'participantId': 3,
#        'physicalDamage': 75,
#        'spellName': 'nasusq',
#        'spellSlot': 0,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'Nasus',
#        'participantId': 3,
#        'physicalDamage': 52,
#        'spellName': 'nasusbasicattack2',
#        'spellSlot': 65,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'Nasus',
#        'participantId': 3,
#        'physicalDamage': 52,
#        'spellName': 'nasusbasicattack',
#        'spellSlot': 64,
#        'trueDamage': 0,
#        'type': 'OTHER'}],
#      'victimId': 8},
#     {'killType': 'KILL_FIRST_BLOOD',
#      'killerId': 3,
#      'position': {'x': 12114, 'y': 7950},
#      'timestamp': 78756,
#      'type': 'CHAMPION_SPECIAL_KILL'},
#     {'level': 2, 'participantId': 2, 'timestamp': 102308, 'type': 'LEVEL_UP'},
#     {'levelUpType': 'NORMAL',
#      'participantId': 2,
#      'skillSlot': 2,
#      'timestamp': 103894,
#      'type': 'SKILL_LEVEL_UP'},
#     {'levelUpType': 'NORMAL',
#      'participantId': 6,
#      'skillSlot': 3,
#      'timestamp': 104026,
#      'type': 'SKILL_LEVEL_UP'},
#     {'assistingParticipantIds': [2, 4, 5],
#      'bounty': 300,
#      'killStreakLength': 1,
#      'killerId': 3,
#      'position': {'x': 11788, 'y': 7248},
#      'timestamp': 106206,
#      'type': 'CHAMPION_KILL',
#      'victimDamageDealt': [{'basic': True,
#        'magicDamage': 0,
#        'name': 'Shyvana',
#        'participantId': 3,
#        'physicalDamage': 48,
#        'spellName': 'shyvanabasicattack2',
#        'spellSlot': 65,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 0,
#        'name': 'Shyvana',
#        'participantId': 3,
#        'physicalDamage': 14,
#        'spellName': '',
#        'spellSlot': -1,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'Shyvana',
#        'participantId': 4,
#        'physicalDamage': 54,
#        'spellName': 'shyvanabasicattack',
#        'spellSlot': 64,
#        'trueDamage': 0,
#        'type': 'OTHER'}],
#      'victimDamageReceived': [{'basic': False,
#        'magicDamage': 0,
#        'name': 'Nasus',
#        'participantId': 3,
#        'physicalDamage': 65,
#        'spellName': 'nasusq',
#        'spellSlot': 0,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'Nasus',
#        'participantId': 3,
#        'physicalDamage': 44,
#        'spellName': 'nasusbasicattack',
#        'spellSlot': 64,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'Nasus',
#        'participantId': 3,
#        'physicalDamage': 44,
#        'spellName': 'nasusbasicattack2',
#        'spellSlot': 65,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 70,
#        'name': 'Lux',
#        'participantId': 5,
#        'physicalDamage': 0,
#        'spellName': 'luxlightbinding',
#        'spellSlot': 0,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'Lux',
#        'participantId': 5,
#        'physicalDamage': 36,
#        'spellName': 'luxbasicattack',
#        'spellSlot': 64,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 25,
#        'name': 'Lux',
#        'participantId': 5,
#        'physicalDamage': 0,
#        'spellName': '',
#        'spellSlot': -1,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 18,
#        'name': 'Lux',
#        'participantId': 5,
#        'physicalDamage': 0,
#        'spellName': 'luxilluminationpassive',
#        'spellSlot': 63,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'Lux',
#        'participantId': 5,
#        'physicalDamage': 36,
#        'spellName': 'luxbasicattack2',
#        'spellSlot': 65,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'DrMundo',
#        'participantId': 4,
#        'physicalDamage': 48,
#        'spellName': 'drmundobasicattack3',
#        'spellSlot': 66,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 10,
#        'name': 'DrMundo',
#        'participantId': 4,
#        'physicalDamage': 0,
#        'spellName': '',
#        'spellSlot': -1,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'DrMundo',
#        'participantId': 4,
#        'physicalDamage': 97,
#        'spellName': 'drmundobasicattack',
#        'spellSlot': 64,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 58,
#        'name': 'DrMundo',
#        'participantId': 4,
#        'physicalDamage': 0,
#        'spellName': 'drmundoq',
#        'spellSlot': 0,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 21,
#        'name': 'Warwick',
#        'participantId': 2,
#        'physicalDamage': 0,
#        'spellName': 'warwickp',
#        'spellSlot': 63,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': True,
#        'magicDamage': 0,
#        'name': 'Warwick',
#        'participantId': 2,
#        'physicalDamage': 48,
#        'spellName': 'warwickbasicattack2',
#        'spellSlot': 65,
#        'trueDamage': 0,
#        'type': 'OTHER'},
#       {'basic': False,
#        'magicDamage': 89,
#        'name': 'Warwick',
#        'participantId': 2,
#        'physicalDamage': 0,
#        'spellName': 'warwickq',
#        'spellSlot': 0,
#        'trueDamage': 0,
#        'type': 'OTHER'}],
#      'victimId': 7},
#     {'itemId': 1042,
#      'participantId': 3,
#      'timestamp': 120013,
#      'type': 'ITEM_DESTROYED'},
#     {'itemId': 3051,
#      'participantId': 3,
#      'timestamp': 120013,
#      'type': 'ITEM_PURCHASED'}],
#    'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 34,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 77,
#       'attackSpeed': 110,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 568,
#       'healthMax': 571,
#       'healthRegen': 7,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 30,
#       'movementSpeed': 335,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 348,
#       'powerMax': 348,
#       'powerRegen': 16,
#       'spellVamp': 0},
#      'currentGold': 84,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 387,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 8,
#       'totalDamageDone': 2772,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 8,
#       'trueDamageDone': 2385,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 3,
#      'participantId': 1,
#      'position': {'x': 2013, 'y': 12080},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 584,
#      'xp': 181},
#     '2': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 41,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 72,
#       'attackSpeed': 116,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 234,
#       'healthMax': 611,
#       'healthRegen': 9,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 338,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 292,
#       'powerMax': 305,
#       'powerRegen': 103,
#       'spellVamp': 0},
#      'currentGold': 194,
#      'damageStats': {'magicDamageDone': 909,
#       'magicDamageDoneToChampions': 111,
#       'magicDamageTaken': 367,
#       'physicalDamageDone': 697,
#       'physicalDamageDoneToChampions': 48,
#       'physicalDamageTaken': 584,
#       'totalDamageDone': 2056,
#       'totalDamageDoneToChampions': 159,
#       'totalDamageTaken': 951,
#       'trueDamageDone': 450,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 4,
#      'level': 2,
#      'minionsKilled': 0,
#      'participantId': 2,
#      'position': {'x': 12499, 'y': 5578},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 669,
#      'xp': 332},
#     '3': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 46,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 82,
#       'attackSpeed': 115,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 224,
#       'healthMax': 561,
#       'healthRegen': 18,
#       'lifesteal': 10,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 350,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 326,
#       'powerMax': 326,
#       'powerRegen': 14,
#       'spellVamp': 0},
#      'currentGold': 121,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 286,
#       'physicalDamageDone': 335,
#       'physicalDamageDoneToChampions': 335,
#       'physicalDamageTaken': 225,
#       'totalDamageDone': 335,
#       'totalDamageDoneToChampions': 335,
#       'totalDamageTaken': 511,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 3,
#      'position': {'x': 394, 'y': 461},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 1221,
#      'xp': 13},
#     '4': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 32,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 71,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 463,
#       'healthMax': 678,
#       'healthRegen': 41,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 345,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 0,
#       'powerMax': 0,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 99,
#      'damageStats': {'magicDamageDone': 324,
#       'magicDamageDoneToChampions': 324,
#       'magicDamageTaken': 361,
#       'physicalDamageDone': 349,
#       'physicalDamageDoneToChampions': 230,
#       'physicalDamageTaken': 54,
#       'totalDamageDone': 702,
#       'totalDamageDoneToChampions': 582,
#       'totalDamageTaken': 416,
#       'trueDamageDone': 28,
#       'trueDamageDoneToChampions': 28,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 4,
#      'position': {'x': 11772, 'y': 3793},
#      'timeEnemySpentControlled': 10768,
#      'totalGold': 599,
#      'xp': 13},
#     '5': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 30,
#       'armor': 19,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 54,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 381,
#       'healthMax': 515,
#       'healthRegen': 11,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 30,
#       'movementSpeed': 351,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 441,
#       'powerMax': 530,
#       'powerRegen': 24,
#       'spellVamp': 0},
#      'currentGold': 221,
#      'damageStats': {'magicDamageDone': 391,
#       'magicDamageDoneToChampions': 309,
#       'magicDamageTaken': 154,
#       'physicalDamageDone': 469,
#       'physicalDamageDoneToChampions': 199,
#       'physicalDamageTaken': 71,
#       'totalDamageDone': 860,
#       'totalDamageDoneToChampions': 508,
#       'totalDamageTaken': 226,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 20,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 0,
#      'participantId': 5,
#      'position': {'x': 11315, 'y': 5242},
#      'timeEnemySpentControlled': 10736,
#      'totalGold': 721,
#      'xp': 13},
#     '6': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 33,
#       'armor': 33,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 61,
#       'attackSpeed': 100,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 5,
#       'cooldownReduction': 0,
#       'health': 595,
#       'healthMax': 595,
#       'healthRegen': 18,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 32,
#       'movementSpeed': 340,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 310,
#       'powerMax': 310,
#       'powerRegen': 16,
#       'spellVamp': 0},
#      'currentGold': 42,
#      'damageStats': {'magicDamageDone': 0,
#       'magicDamageDoneToChampions': 0,
#       'magicDamageTaken': 0,
#       'physicalDamageDone': 132,
#       'physicalDamageDoneToChampions': 0,
#       'physicalDamageTaken': 0,
#       'totalDamageDone': 132,
#       'totalDamageDoneToChampions': 0,
#       'totalDamageTaken': 0,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 1,
#      'minionsKilled': 1,
#      'participantId': 6,
#      'position': {'x': 2833, 'y': 13063},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 542,
#      'xp': 60},
#     '7': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 49,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 71,
#       'attackSpeed': 110,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 595,
#       'healthMax': 595,
#       'healthRegen': 17,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 37,
#       'movementSpeed': 473,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 0,
#       'powerMax': 100,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 21,
#      'damageStats': {'magicDamageDone': 61,
# ...
#       'totalDamageDone': 85633,
#       'totalDamageDoneToChampions': 23424,
#       'totalDamageTaken': 9866,
#       'trueDamageDone': 478,
#       'trueDamageDoneToChampions': 134,
#       'trueDamageTaken': 381},
#      'goldPerSecond': 30,
#      'jungleMinionsKilled': 28,
#      'level': 13,
#      'minionsKilled': 49,
#      'participantId': 10,
#      'position': {'x': 2297, 'y': 1466},
#      'timeEnemySpentControlled': 50268,
#      'totalGold': 11552,
#      'xp': 10577}},
#    'timestamp': 1500388},
#   {'events': [{'creatorId': 2,
#      'timestamp': 1501280,
#      'type': 'WARD_PLACED',
#      'wardType': 'UNDEFINED'},
#     {'creatorId': 2,
#      'timestamp': 1503393,
#      'type': 'WARD_PLACED',
#      'wardType': 'UNDEFINED'},
#     {'creatorId': 2,
#      'timestamp': 1505508,
#      'type': 'WARD_PLACED',
#      'wardType': 'UNDEFINED'},
#     {'creatorId': 2,
#      'timestamp': 1507622,
#      'type': 'WARD_PLACED',
#      'wardType': 'UNDEFINED'},
#     {'gameId': 5594247935,
#      'realTimestamp': 1638085441825,
#      'timestamp': 1508019,
#      'type': 'GAME_END',
#      'winningTeam': 200}],
#    'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 63,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 204,
#       'attackSpeed': 202,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 1331,
#       'healthMax': 1417,
#       'healthRegen': 20,
#       'lifesteal': 10,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 34,
#       'movementSpeed': 380,
#       'omnivamp': 4,
#       'physicalVamp': 0,
#       'power': 568,
#       'powerMax': 722,
#       'powerRegen': 30,
#       'spellVamp': 0},
#      'currentGold': 270,
#      'damageStats': {'magicDamageDone': 3003,
#       'magicDamageDoneToChampions': 455,
#       'magicDamageTaken': 11106,
#       'physicalDamageDone': 63753,
#       'physicalDamageDoneToChampions': 8355,
#       'physicalDamageTaken': 3458,
#       'totalDamageDone': 75137,
#       'totalDamageDoneToChampions': 9331,
#       'totalDamageTaken': 14683,
#       'trueDamageDone': 8381,
#       'trueDamageDoneToChampions': 520,
#       'trueDamageTaken': 118},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 0,
#      'level': 12,
#      'minionsKilled': 108,
#      'participantId': 1,
#      'position': {'x': 2010, 'y': 832},
#      'timeEnemySpentControlled': 0,
#      'totalGold': 8040,
#      'xp': 9943},
#     '2': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 185,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 99,
#       'attackSpeed': 150,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 5,
#       'cooldownReduction': 0,
#       'health': 0,
#       'healthMax': 2586,
#       'healthRegen': 22,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 104,
#       'movementSpeed': 679,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 446,
#       'powerMax': 624,
#       'powerRegen': 26,
#       'spellVamp': 0},
#      'currentGold': 293,
#      'damageStats': {'magicDamageDone': 43441,
#       'magicDamageDoneToChampions': 13939,
#       'magicDamageTaken': 25585,
#       'physicalDamageDone': 25089,
#       'physicalDamageDoneToChampions': 5043,
#       'physicalDamageTaken': 14569,
#       'totalDamageDone': 77377,
#       'totalDamageDoneToChampions': 19855,
#       'totalDamageTaken': 40726,
#       'trueDamageDone': 8847,
#       'trueDamageDoneToChampions': 872,
#       'trueDamageTaken': 572},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 68,
#      'level': 12,
#      'minionsKilled': 33,
#      'participantId': 2,
#      'position': {'x': 1456, 'y': 1148},
#      'timeEnemySpentControlled': 251814,
#      'totalGold': 9788,
#      'xp': 9279},
#     '3': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 80,
#       'armorPen': 0,
#       'armorPenPercent': 30,
#       'attackDamage': 209,
#       'attackSpeed': 164,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 0,
#       'healthMax': 1647,
#       'healthRegen': 35,
#       'lifesteal': 16,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 44,
#       'movementSpeed': 388,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 904,
#       'powerMax': 1086,
#       'powerRegen': 24,
#       'spellVamp': 0},
#      'currentGold': 667,
#      'damageStats': {'magicDamageDone': 10035,
#       'magicDamageDoneToChampions': 1323,
#       'magicDamageTaken': 13699,
#       'physicalDamageDone': 76426,
#       'physicalDamageDoneToChampions': 4407,
#       'physicalDamageTaken': 6140,
#       'totalDamageDone': 86461,
#       'totalDamageDoneToChampions': 5731,
#       'totalDamageTaken': 19902,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 62},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 2,
#      'level': 12,
#      'minionsKilled': 105,
#      'participantId': 3,
#      'position': {'x': 1064, 'y': 1150},
#      'timeEnemySpentControlled': 214715,
#      'totalGold': 9010,
#      'xp': 8736},
#     '4': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 126,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 157,
#       'attackSpeed': 132,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 2077,
#       'healthMax': 2406,
#       'healthRegen': 122,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 104,
#       'movementSpeed': 405,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 0,
#       'powerMax': 0,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 679,
#      'damageStats': {'magicDamageDone': 42565,
#       'magicDamageDoneToChampions': 1735,
#       'magicDamageTaken': 3284,
#       'physicalDamageDone': 57369,
#       'physicalDamageDoneToChampions': 1292,
#       'physicalDamageTaken': 6218,
#       'totalDamageDone': 102902,
#       'totalDamageDoneToChampions': 3302,
#       'totalDamageTaken': 9503,
#       'trueDamageDone': 2967,
#       'trueDamageDoneToChampions': 274,
#       'trueDamageTaken': 0},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 48,
#      'level': 12,
#      'minionsKilled': 95,
#      'participantId': 4,
#      'position': {'x': 1965, 'y': 7604},
#      'timeEnemySpentControlled': 210430,
#      'totalGold': 7489,
#      'xp': 8604},
#     '5': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 252,
#       'armor': 58,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 86,
#       'attackSpeed': 119,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 0,
#       'healthMax': 1647,
#       'healthRegen': 21,
#       'lifesteal': 0,
#       'magicPen': 29,
#       'magicPenPercent': 0,
#       'magicResist': 34,
#       'movementSpeed': 412,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 1561,
#       'powerMax': 1561,
#       'powerRegen': 63,
#       'spellVamp': 0},
#      'currentGold': 638,
#      'damageStats': {'magicDamageDone': 32621,
#       'magicDamageDoneToChampions': 10805,
#       'magicDamageTaken': 13076,
#       'physicalDamageDone': 4028,
#       'physicalDamageDoneToChampions': 656,
#       'physicalDamageTaken': 5298,
#       'totalDamageDone': 36650,
#       'totalDamageDoneToChampions': 11461,
#       'totalDamageTaken': 18495,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 120},
#      'goldPerSecond': 30,
#      'jungleMinionsKilled': 0,
#      'level': 12,
#      'minionsKilled': 27,
#      'participantId': 5,
#      'position': {'x': 1618, 'y': 1203},
#      'timeEnemySpentControlled': 181423,
#      'totalGold': 7537,
#      'xp': 8989},
#     '6': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 243,
#       'armor': 126,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 97,
#       'attackSpeed': 147,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 30,
#       'cooldownReduction': 0,
#       'health': 182,
#       'healthMax': 2235,
#       'healthRegen': 39,
#       'lifesteal': 0,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 53,
#       'movementSpeed': 417,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 1906,
#       'powerMax': 1906,
#       'powerRegen': 35,
#       'spellVamp': 0},
#      'currentGold': 1649,
#      'damageStats': {'magicDamageDone': 78551,
#       'magicDamageDoneToChampions': 22246,
#       'magicDamageTaken': 8799,
#       'physicalDamageDone': 7753,
#       'physicalDamageDoneToChampions': 865,
#       'physicalDamageTaken': 16925,
#       'totalDamageDone': 86305,
#       'totalDamageDoneToChampions': 23112,
#       'totalDamageTaken': 26375,
#       'trueDamageDone': 0,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 650},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 8,
#      'level': 14,
#      'minionsKilled': 102,
#      'participantId': 6,
#      'position': {'x': 2250, 'y': 1131},
#      'timeEnemySpentControlled': 247013,
#      'totalGold': 10399,
#      'xp': 12193},
#     '7': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 243,
#       'armor': 88,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 95,
#       'attackSpeed': 186,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 714,
#       'healthMax': 1428,
#       'healthRegen': 31,
#       'lifesteal': 0,
#       'magicPen': 18,
#       'magicPenPercent': 0,
#       'magicResist': 57,
#       'movementSpeed': 408,
#       'omnivamp': 4,
#       'physicalVamp': 0,
#       'power': 100,
#       'powerMax': 100,
#       'powerRegen': 16,
#       'spellVamp': 0},
#      'currentGold': 467,
#      'damageStats': {'magicDamageDone': 40754,
#       'magicDamageDoneToChampions': 5862,
#       'magicDamageTaken': 5223,
#       'physicalDamageDone': 15928,
#       'physicalDamageDoneToChampions': 1208,
#       'physicalDamageTaken': 13174,
#       'totalDamageDone': 68734,
#       'totalDamageDoneToChampions': 7279,
#       'totalDamageTaken': 18555,
#       'trueDamageDone': 12050,
#       'trueDamageDoneToChampions': 208,
#       'trueDamageTaken': 157},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 58,
#      'level': 11,
#      'minionsKilled': 1,
#      'participantId': 7,
#      'position': {'x': 5231, 'y': 5960},
#      'timeEnemySpentControlled': 45815,
#      'totalGold': 6937,
#      'xp': 8155},
#     '8': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 158,
#       'armor': 70,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 91,
#       'attackSpeed': 121,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 1244,
#       'healthMax': 1858,
#       'healthRegen': 24,
#       'lifesteal': 0,
#       'magicPen': 24,
#       'magicPenPercent': 0,
#       'magicResist': 36,
#       'movementSpeed': 398,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 420,
#       'powerMax': 1724,
#       'powerRegen': 35,
#       'spellVamp': 0},
#      'currentGold': 2064,
#      'damageStats': {'magicDamageDone': 79837,
#       'magicDamageDoneToChampions': 13904,
#       'magicDamageTaken': 3140,
#       'physicalDamageDone': 5992,
#       'physicalDamageDoneToChampions': 262,
#       'physicalDamageTaken': 2872,
#       'totalDamageDone': 90054,
#       'totalDamageDoneToChampions': 14697,
#       'totalDamageTaken': 6112,
#       'trueDamageDone': 4225,
#       'trueDamageDoneToChampions': 530,
#       'trueDamageTaken': 100},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 2,
#      'level': 14,
#      'minionsKilled': 99,
#      'participantId': 8,
#      'position': {'x': 2450, 'y': 1879},
#      'timeEnemySpentControlled': 246980,
#      'totalGold': 8369,
#      'xp': 12438},
#     '9': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 0,
#       'armor': 71,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 306,
#       'attackSpeed': 255,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 1641,
#       'healthMax': 1641,
#       'healthRegen': 34,
#       'lifesteal': 30,
#       'magicPen': 0,
#       'magicPenPercent': 0,
#       'magicResist': 55,
#       'movementSpeed': 517,
#       'omnivamp': 0,
#       'physicalVamp': 0,
#       'power': 320,
#       'powerMax': 320,
#       'powerRegen': 0,
#       'spellVamp': 0},
#      'currentGold': 187,
#      'damageStats': {'magicDamageDone': 8996,
#       'magicDamageDoneToChampions': 1096,
#       'magicDamageTaken': 7668,
#       'physicalDamageDone': 141293,
#       'physicalDamageDoneToChampions': 12940,
#       'physicalDamageTaken': 14061,
#       'totalDamageDone': 152895,
#       'totalDamageDoneToChampions': 14036,
#       'totalDamageTaken': 24107,
#       'trueDamageDone': 2605,
#       'trueDamageDoneToChampions': 0,
#       'trueDamageTaken': 2377},
#      'goldPerSecond': 0,
#      'jungleMinionsKilled': 14,
#      'level': 14,
#      'minionsKilled': 178,
#      'participantId': 9,
#      'position': {'x': 14340, 'y': 14391},
#      'timeEnemySpentControlled': 93729,
#      'totalGold': 12207,
#      'xp': 12161},
#     '10': {'championStats': {'abilityHaste': 0,
#       'abilityPower': 399,
#       'armor': 105,
#       'armorPen': 0,
#       'armorPenPercent': 0,
#       'attackDamage': 89,
#       'attackSpeed': 119,
#       'bonusArmorPenPercent': 0,
#       'bonusMagicPenPercent': 0,
#       'ccReduction': 0,
#       'cooldownReduction': 0,
#       'health': 1447,
#       'healthMax': 1761,
#       'healthRegen': 338,
#       'lifesteal': 0,
#       'magicPen': 18,
#       'magicPenPercent': 0,
#       'magicResist': 35,
#       'movementSpeed': 421,
#       'omnivamp': 4,
#       'physicalVamp': 0,
#       'power': 875,
#       'powerMax': 1298,
#       'powerRegen': 68,
#       'spellVamp': 0},
#      'currentGold': 1515,
#      'damageStats': {'magicDamageDone': 80488,
#       'magicDamageDoneToChampions': 22254,
#       'magicDamageTaken': 5706,
#       'physicalDamageDone': 4666,
#       'physicalDamageDoneToChampions': 1036,
#       'physicalDamageTaken': 4096,
#       'totalDamageDone': 85633,
#       'totalDamageDoneToChampions': 23424,
#       'totalDamageTaken': 10185,
#       'trueDamageDone': 478,
#       'trueDamageDoneToChampions': 134,
#       'trueDamageTaken': 381},
#      'goldPerSecond': 30,
#      'jungleMinionsKilled': 28,
#      'level': 13,
#      'minionsKilled': 49,
#      'participantId': 10,
#      'position': {'x': 1644, 'y': 712},
#      'timeEnemySpentControlled': 50268,
#      'totalGold': 11569,
#      'xp': 10577}},
#    'timestamp': 1508019}],
#  'gameId': 5594247935,
#  'participants': [{'participantId': 1,
#    'puuid': 'qVWqv7rwyHKfGLXeWOu3b2jmVSjldDZjGgjcBY1mVzsShkzvq4jJY9kj1J07q1QO7cAEhLKwFNehCg'},
#   {'participantId': 2,
#    'puuid': 'YBdhMbsuCJOpjJIk1rG04eq0Y8JHIM1P4QCYZU_nT3UMCR42RHusqd8AzKona7IYuGEPlfea5uBzUg'},
#   {'participantId': 3,
#    'puuid': 'TZWGlTAsoz0pywenGS8Wx7haUfT8pc-CrHT7z5TtWr07OFoHLsqh1UV5wJQOaeRCnHMxvUhgILJWNw'},
#   {'participantId': 4,
#    'puuid': 'jJdbley4VpamDn1qyQu6KEttNmcTOu40oCqh0naV7XGxUqbWXc4J0pW9knzJ-qIk73_u5iurBx694w'},
#   {'participantId': 5,
#    'puuid': '35jOwMpIRQikJLzJot0UvirktktiHdKeeoijAeJmnXdjOzgf4fyozTz97oVhgq1BVO8zY5AL76gyrA'},
#   {'participantId': 6,
#    'puuid': 'pVJz-4Se8YoPjkHWbDAkN10vcIkcsWYk07MbqRVDAXsih9jSh8z6rc32cSefTR4qLVCJYaFqrTicjw'},
#   {'participantId': 7,
#    'puuid': '7qh93BEwARilTztBJnXw5C_IomC3JMwq_TTsYsRrmvfnLSBKuSU-mRETl_rnD8Oz7WdTNjuUwGNa3w'},
#   {'participantId': 8,
#    'puuid': 'c6B3UUueay0dctqC8P5Ta4Luj2aFBYfxvZuEAYxrmGSwqHRI1eL5n04ElL8c7avxZMOCJlR0sXvUng'},
#   {'participantId': 9,
#    'puuid': 'z1U2_HaWAWQ6IQCINQoxhN3jyY7PuPOElRlxmfe0WpsXys4y5qZsdEO3cyJuewTTK597nr-YWHqhdQ'},
#   {'participantId': 10,
#    'puuid': 'Tdu7l_UaZGB6-jypNp0wt5jPjSNJkUHZRB-cjxR2873FEkOu1xqdmNoNCGaeomDaDmFS806MIsQ5fw'}]}

# %%
df2 = json_normalize(timeline)
df2
# Out:
#    frameInterval  ...                                       participants
# 0          60000  ...  [{'participantId': 1, 'puuid': 'qVWqv7rwyHKfGL...
#
# [1 rows x 4 columns]

# %%
json_normalize(df2['frames']).loc[0,0]
# Out:
# {'events': [{'realTimestamp': 1638083933774,
#    'timestamp': 0,
#    'type': 'PAUSE_END'}],
#  'timestamp': 0,
#  'participantFrames.1.championStats.abilityHaste': 0,
#  'participantFrames.1.championStats.abilityPower': 0,
#  'participantFrames.1.championStats.armor': 28,
#  'participantFrames.1.championStats.armorPen': 0,
#  'participantFrames.1.championStats.armorPenPercent': 0,
#  'participantFrames.1.championStats.attackDamage': 25,
#  'participantFrames.1.championStats.attackSpeed': 100,
#  'participantFrames.1.championStats.bonusArmorPenPercent': 0,
#  'participantFrames.1.championStats.bonusMagicPenPercent': 0,
#  'participantFrames.1.championStats.ccReduction': 0,
#  'participantFrames.1.championStats.cooldownReduction': 0,
#  'participantFrames.1.championStats.health': 571,
#  'participantFrames.1.championStats.healthMax': 571,
#  'participantFrames.1.championStats.healthRegen': 0,
#  'participantFrames.1.championStats.lifesteal': 0,
#  'participantFrames.1.championStats.magicPen': 0,
#  'participantFrames.1.championStats.magicPenPercent': 0,
#  'participantFrames.1.championStats.magicResist': 30,
#  'participantFrames.1.championStats.movementSpeed': 335,
#  'participantFrames.1.championStats.omnivamp': 0,
#  'participantFrames.1.championStats.physicalVamp': 0,
#  'participantFrames.1.championStats.power': 348,
#  'participantFrames.1.championStats.powerMax': 348,
#  'participantFrames.1.championStats.powerRegen': 0,
#  'participantFrames.1.championStats.spellVamp': 0,
#  'participantFrames.1.currentGold': 500,
#  'participantFrames.1.damageStats.magicDamageDone': 0,
#  'participantFrames.1.damageStats.magicDamageDoneToChampions': 0,
#  'participantFrames.1.damageStats.magicDamageTaken': 0,
#  'participantFrames.1.damageStats.physicalDamageDone': 0,
#  'participantFrames.1.damageStats.physicalDamageDoneToChampions': 0,
#  'participantFrames.1.damageStats.physicalDamageTaken': 0,
#  'participantFrames.1.damageStats.totalDamageDone': 0,
#  'participantFrames.1.damageStats.totalDamageDoneToChampions': 0,
#  'participantFrames.1.damageStats.totalDamageTaken': 0,
#  'participantFrames.1.damageStats.trueDamageDone': 0,
#  'participantFrames.1.damageStats.trueDamageDoneToChampions': 0,
#  'participantFrames.1.damageStats.trueDamageTaken': 0,
#  'participantFrames.1.goldPerSecond': 0,
#  'participantFrames.1.jungleMinionsKilled': 0,
#  'participantFrames.1.level': 1,
#  'participantFrames.1.minionsKilled': 0,
#  'participantFrames.1.participantId': 1,
#  'participantFrames.1.position.x': 554,
#  'participantFrames.1.position.y': 581,
#  'participantFrames.1.timeEnemySpentControlled': 0,
#  'participantFrames.1.totalGold': 500,
#  'participantFrames.1.xp': 0,
#  'participantFrames.2.championStats.abilityHaste': 0,
#  'participantFrames.2.championStats.abilityPower': 0,
#  'participantFrames.2.championStats.armor': 33,
#  'participantFrames.2.championStats.armorPen': 0,
#  'participantFrames.2.championStats.armorPenPercent': 0,
#  'participantFrames.2.championStats.attackDamage': 25,
#  'participantFrames.2.championStats.attackSpeed': 100,
#  'participantFrames.2.championStats.bonusArmorPenPercent': 0,
#  'participantFrames.2.championStats.bonusMagicPenPercent': 0,
#  'participantFrames.2.championStats.ccReduction': 0,
#  'participantFrames.2.championStats.cooldownReduction': 0,
#  'participantFrames.2.championStats.health': 550,
#  'participantFrames.2.championStats.healthMax': 550,
#  'participantFrames.2.championStats.healthRegen': 0,
#  'participantFrames.2.championStats.lifesteal': 0,
#  'participantFrames.2.championStats.magicPen': 0,
#  'participantFrames.2.championStats.magicPenPercent': 0,
#  'participantFrames.2.championStats.magicResist': 32,
#  'participantFrames.2.championStats.movementSpeed': 335,
#  'participantFrames.2.championStats.omnivamp': 0,
#  'participantFrames.2.championStats.physicalVamp': 0,
#  'participantFrames.2.championStats.power': 280,
#  'participantFrames.2.championStats.powerMax': 280,
#  'participantFrames.2.championStats.powerRegen': 0,
#  'participantFrames.2.championStats.spellVamp': 0,
#  'participantFrames.2.currentGold': 500,
#  'participantFrames.2.damageStats.magicDamageDone': 0,
#  'participantFrames.2.damageStats.magicDamageDoneToChampions': 0,
#  'participantFrames.2.damageStats.magicDamageTaken': 0,
#  'participantFrames.2.damageStats.physicalDamageDone': 0,
#  'participantFrames.2.damageStats.physicalDamageDoneToChampions': 0,
#  'participantFrames.2.damageStats.physicalDamageTaken': 0,
#  'participantFrames.2.damageStats.totalDamageDone': 0,
#  'participantFrames.2.damageStats.totalDamageDoneToChampions': 0,
#  'participantFrames.2.damageStats.totalDamageTaken': 0,
#  'participantFrames.2.damageStats.trueDamageDone': 0,
#  'participantFrames.2.damageStats.trueDamageDoneToChampions': 0,
#  'participantFrames.2.damageStats.trueDamageTaken': 0,
#  'participantFrames.2.goldPerSecond': 0,
#  'participantFrames.2.jungleMinionsKilled': 0,
#  'participantFrames.2.level': 1,
#  'participantFrames.2.minionsKilled': 0,
#  'participantFrames.2.participantId': 2,
#  'participantFrames.2.position.x': 557,
#  'participantFrames.2.position.y': 345,
#  'participantFrames.2.timeEnemySpentControlled': 0,
#  'participantFrames.2.totalGold': 500,
#  'participantFrames.2.xp': 0,
#  'participantFrames.3.championStats.abilityHaste': 0,
#  'participantFrames.3.championStats.abilityPower': 0,
#  'participantFrames.3.championStats.armor': 34,
#  'participantFrames.3.championStats.armorPen': 0,
#  'participantFrames.3.championStats.armorPenPercent': 0,
#  'participantFrames.3.championStats.attackDamage': 25,
#  'participantFrames.3.championStats.attackSpeed': 100,
#  'participantFrames.3.championStats.bonusArmorPenPercent': 0,
#  'participantFrames.3.championStats.bonusMagicPenPercent': 0,
#  'participantFrames.3.championStats.ccReduction': 0,
#  'participantFrames.3.championStats.cooldownReduction': 0,
#  'participantFrames.3.championStats.health': 561,
#  'participantFrames.3.championStats.healthMax': 561,
#  'participantFrames.3.championStats.healthRegen': 0,
#  'participantFrames.3.championStats.lifesteal': 0,
#  'participantFrames.3.championStats.magicPen': 0,
#  'participantFrames.3.championStats.magicPenPercent': 0,
#  'participantFrames.3.championStats.magicResist': 32,
#  'participantFrames.3.championStats.movementSpeed': 350,
#  'participantFrames.3.championStats.omnivamp': 0,
#  'participantFrames.3.championStats.physicalVamp': 0,
#  'participantFrames.3.championStats.power': 326,
#  'participantFrames.3.championStats.powerMax': 326,
#  'participantFrames.3.championStats.powerRegen': 0,
#  'participantFrames.3.championStats.spellVamp': 0,
#  'participantFrames.3.currentGold': 500,
#  'participantFrames.3.damageStats.magicDamageDone': 0,
#  'participantFrames.3.damageStats.magicDamageDoneToChampions': 0,
#  'participantFrames.3.damageStats.magicDamageTaken': 0,
#  'participantFrames.3.damageStats.physicalDamageDone': 0,
#  'participantFrames.3.damageStats.physicalDamageDoneToChampions': 0,
#  'participantFrames.3.damageStats.physicalDamageTaken': 0,
#  'participantFrames.3.damageStats.totalDamageDone': 0,
#  'participantFrames.3.damageStats.totalDamageDoneToChampions': 0,
#  'participantFrames.3.damageStats.totalDamageTaken': 0,
#  'participantFrames.3.damageStats.trueDamageDone': 0,
#  'participantFrames.3.damageStats.trueDamageDoneToChampions': 0,
#  'participantFrames.3.damageStats.trueDamageTaken': 0,
#  'participantFrames.3.goldPerSecond': 0,
#  'participantFrames.3.jungleMinionsKilled': 0,
#  'participantFrames.3.level': 1,
#  'participantFrames.3.minionsKilled': 0,
#  'participantFrames.3.participantId': 3,
#  'participantFrames.3.position.x': 335,
#  'participantFrames.3.position.y': 269,
#  'participantFrames.3.timeEnemySpentControlled': 0,
#  'participantFrames.3.totalGold': 500,
#  'participantFrames.3.xp': 0,
#  'participantFrames.4.championStats.abilityHaste': 0,
#  'participantFrames.4.championStats.abilityPower': 0,
#  'participantFrames.4.championStats.armor': 32,
#  'participantFrames.4.championStats.armorPen': 0,
#  'participantFrames.4.championStats.armorPenPercent': 0,
#  'participantFrames.4.championStats.attackDamage': 25,
#  'participantFrames.4.championStats.attackSpeed': 100,
#  'participantFrames.4.championStats.bonusArmorPenPercent': 0,
#  'participantFrames.4.championStats.bonusMagicPenPercent': 0,
#  'participantFrames.4.championStats.ccReduction': 0,
#  'participantFrames.4.championStats.cooldownReduction': 0,
#  'participantFrames.4.championStats.health': 583,
#  'participantFrames.4.championStats.healthMax': 583,
#  'participantFrames.4.championStats.healthRegen': 0,
#  'participantFrames.4.championStats.lifesteal': 0,
#  'participantFrames.4.championStats.magicPen': 0,
#  'participantFrames.4.championStats.magicPenPercent': 0,
#  'participantFrames.4.championStats.magicResist': 32,
#  'participantFrames.4.championStats.movementSpeed': 345,
#  'participantFrames.4.championStats.omnivamp': 0,
#  'participantFrames.4.championStats.physicalVamp': 0,
#  'participantFrames.4.championStats.power': 0,
#  'participantFrames.4.championStats.powerMax': 0,
#  'participantFrames.4.championStats.powerRegen': 0,
#  'participantFrames.4.championStats.spellVamp': 0,
#  'participantFrames.4.currentGold': 500,
#  'participantFrames.4.damageStats.magicDamageDone': 0,
#  'participantFrames.4.damageStats.magicDamageDoneToChampions': 0,
#  'participantFrames.4.damageStats.magicDamageTaken': 0,
#  'participantFrames.4.damageStats.physicalDamageDone': 0,
#  'participantFrames.4.damageStats.physicalDamageDoneToChampions': 0,
#  'participantFrames.4.damageStats.physicalDamageTaken': 0,
#  'participantFrames.4.damageStats.totalDamageDone': 0,
#  'participantFrames.4.damageStats.totalDamageDoneToChampions': 0,
#  'participantFrames.4.damageStats.totalDamageTaken': 0,
#  'participantFrames.4.damageStats.trueDamageDone': 0,
#  'participantFrames.4.damageStats.trueDamageDoneToChampions': 0,
#  'participantFrames.4.damageStats.trueDamageTaken': 0,
#  'participantFrames.4.goldPerSecond': 0,
#  'participantFrames.4.jungleMinionsKilled': 0,
#  'participantFrames.4.level': 1,
#  'participantFrames.4.minionsKilled': 0,
#  'participantFrames.4.participantId': 4,
#  'participantFrames.4.position.x': 194,
#  'participantFrames.4.position.y': 457,
#  'participantFrames.4.timeEnemySpentControlled': 0,
#  'participantFrames.4.totalGold': 500,
#  'participantFrames.4.xp': 0,
#  'participantFrames.5.championStats.abilityHaste': 0,
#  'participantFrames.5.championStats.abilityPower': 0,
#  'participantFrames.5.championStats.armor': 19,
#  'participantFrames.5.championStats.armorPen': 0,
#  'participantFrames.5.championStats.armorPenPercent': 0,
#  'participantFrames.5.championStats.attackDamage': 25,
#  'participantFrames.5.championStats.attackSpeed': 100,
#  'participantFrames.5.championStats.bonusArmorPenPercent': 0,
#  'participantFrames.5.championStats.bonusMagicPenPercent': 0,
#  'participantFrames.5.championStats.ccReduction': 0,
#  'participantFrames.5.championStats.cooldownReduction': 0,
#  'participantFrames.5.championStats.health': 490,
#  'participantFrames.5.championStats.healthMax': 490,
#  'participantFrames.5.championStats.healthRegen': 0,
#  'participantFrames.5.championStats.lifesteal': 0,
#  'participantFrames.5.championStats.magicPen': 0,
#  'participantFrames.5.championStats.magicPenPercent': 0,
#  'participantFrames.5.championStats.magicResist': 30,
#  'participantFrames.5.championStats.movementSpeed': 330,
#  'participantFrames.5.championStats.omnivamp': 0,
#  'participantFrames.5.championStats.physicalVamp': 0,
#  'participantFrames.5.championStats.power': 480,
#  'participantFrames.5.championStats.powerMax': 480,
#  'participantFrames.5.championStats.powerRegen': 0,
#  'participantFrames.5.championStats.spellVamp': 0,
#  'participantFrames.5.currentGold': 500,
#  'participantFrames.5.damageStats.magicDamageDone': 0,
#  'participantFrames.5.damageStats.magicDamageDoneToChampions': 0,
#  'participantFrames.5.damageStats.magicDamageTaken': 0,
#  'participantFrames.5.damageStats.physicalDamageDone': 0,
#  'participantFrames.5.damageStats.physicalDamageDoneToChampions': 0,
#  'participantFrames.5.damageStats.physicalDamageTaken': 0,
#  'participantFrames.5.damageStats.totalDamageDone': 0,
#  'participantFrames.5.damageStats.totalDamageDoneToChampions': 0,
#  'participantFrames.5.damageStats.totalDamageTaken': 0,
#  'participantFrames.5.damageStats.trueDamageDone': 0,
#  'participantFrames.5.damageStats.trueDamageDoneToChampions': 0,
#  'participantFrames.5.damageStats.trueDamageTaken': 0,
#  'participantFrames.5.goldPerSecond': 0,
#  'participantFrames.5.jungleMinionsKilled': 0,
#  'participantFrames.5.level': 1,
#  'participantFrames.5.minionsKilled': 0,
#  'participantFrames.5.participantId': 5,
#  'participantFrames.5.position.x': 329,
#  'participantFrames.5.position.y': 650,
#  'participantFrames.5.timeEnemySpentControlled': 0,
#  'participantFrames.5.totalGold': 500,
#  'participantFrames.5.xp': 0,
#  'participantFrames.6.championStats.abilityHaste': 0,
#  'participantFrames.6.championStats.abilityPower': 0,
#  'participantFrames.6.championStats.armor': 27,
#  'participantFrames.6.championStats.armorPen': 0,
#  'participantFrames.6.championStats.armorPenPercent': 0,
#  'participantFrames.6.championStats.attackDamage': 25,
#  'participantFrames.6.championStats.attackSpeed': 100,
#  'participantFrames.6.championStats.bonusArmorPenPercent': 0,
#  'participantFrames.6.championStats.bonusMagicPenPercent': 0,
#  'participantFrames.6.championStats.ccReduction': 0,
#  'participantFrames.6.championStats.cooldownReduction': 0,
#  'participantFrames.6.championStats.health': 525,
#  'participantFrames.6.championStats.healthMax': 525,
#  'participantFrames.6.championStats.healthRegen': 0,
#  'participantFrames.6.championStats.lifesteal': 0,
#  'participantFrames.6.championStats.magicPen': 0,
#  'participantFrames.6.championStats.magicPenPercent': 0,
#  'participantFrames.6.championStats.magicResist': 32,
#  'participantFrames.6.championStats.movementSpeed': 340,
#  'participantFrames.6.championStats.omnivamp': 0,
#  'participantFrames.6.championStats.physicalVamp': 0,
#  'participantFrames.6.championStats.power': 310,
#  'participantFrames.6.championStats.powerMax': 310,
#  'participantFrames.6.championStats.powerRegen': 0,
#  'participantFrames.6.championStats.spellVamp': 0,
#  'participantFrames.6.currentGold': 500,
#  'participantFrames.6.damageStats.magicDamageDone': 0,
#  'participantFrames.6.damageStats.magicDamageDoneToChampions': 0,
#  'participantFrames.6.damageStats.magicDamageTaken': 0,
#  'participantFrames.6.damageStats.physicalDamageDone': 0,
#  'participantFrames.6.damageStats.physicalDamageDoneToChampions': 0,
#  'participantFrames.6.damageStats.physicalDamageTaken': 0,
#  'participantFrames.6.damageStats.totalDamageDone': 0,
#  'participantFrames.6.damageStats.totalDamageDoneToChampions': 0,
#  'participantFrames.6.damageStats.totalDamageTaken': 0,
#  'participantFrames.6.damageStats.trueDamageDone': 0,
#  'participantFrames.6.damageStats.trueDamageDoneToChampions': 0,
#  'participantFrames.6.damageStats.trueDamageTaken': 0,
#  'participantFrames.6.goldPerSecond': 0,
#  'participantFrames.6.jungleMinionsKilled': 0,
#  'participantFrames.6.level': 1,
#  'participantFrames.6.minionsKilled': 0,
#  'participantFrames.6.participantId': 6,
#  'participantFrames.6.position.x': 14180,
#  'participantFrames.6.position.y': 14271,
#  'participantFrames.6.timeEnemySpentControlled': 0,
#  'participantFrames.6.totalGold': 500,
#  'participantFrames.6.xp': 0,
#  'participantFrames.7.championStats.abilityHaste': 0,
#  'participantFrames.7.championStats.abilityPower': 0,
#  'participantFrames.7.championStats.armor': 38,
#  'participantFrames.7.championStats.armorPen': 0,
#  'participantFrames.7.championStats.armorPenPercent': 0,
#  'participantFrames.7.championStats.attackDamage': 25,
#  'participantFrames.7.championStats.attackSpeed': 100,
#  'participantFrames.7.championStats.bonusArmorPenPercent': 0,
#  'participantFrames.7.championStats.bonusMagicPenPercent': 0,
#  'participantFrames.7.championStats.ccReduction': 0,
#  'participantFrames.7.championStats.cooldownReduction': 0,
#  'participantFrames.7.championStats.health': 595,
#  'participantFrames.7.championStats.healthMax': 595,
#  'participantFrames.7.championStats.healthRegen': 0,
#  'participantFrames.7.championStats.lifesteal': 0,
#  'participantFrames.7.championStats.magicPen': 0,
#  'participantFrames.7.championStats.magicPenPercent': 0,
#  'participantFrames.7.championStats.magicResist': 32,
#  'participantFrames.7.championStats.movementSpeed': 350,
#  'participantFrames.7.championStats.omnivamp': 0,
#  'participantFrames.7.championStats.physicalVamp': 0,
#  'participantFrames.7.championStats.power': 0,
#  'participantFrames.7.championStats.powerMax': 100,
#  'participantFrames.7.championStats.powerRegen': 0,
#  'participantFrames.7.championStats.spellVamp': 0,
#  'participantFrames.7.currentGold': 500,
#  'participantFrames.7.damageStats.magicDamageDone': 0,
#  'participantFrames.7.damageStats.magicDamageDoneToChampions': 0,
#  'participantFrames.7.damageStats.magicDamageTaken': 0,
#  'participantFrames.7.damageStats.physicalDamageDone': 0,
#  'participantFrames.7.damageStats.physicalDamageDoneToChampions': 0,
#  'participantFrames.7.damageStats.physicalDamageTaken': 0,
#  'participantFrames.7.damageStats.totalDamageDone': 0,
#  'participantFrames.7.damageStats.totalDamageDoneToChampions': 0,
#  'participantFrames.7.damageStats.totalDamageTaken': 0,
#  'participantFrames.7.damageStats.trueDamageDone': 0,
#  'participantFrames.7.damageStats.trueDamageDoneToChampions': 0,
#  'participantFrames.7.damageStats.trueDamageTaken': 0,
#  'participantFrames.7.goldPerSecond': 0,
#  'participantFrames.7.jungleMinionsKilled': 0,
#  'participantFrames.7.level': 1,
#  'participantFrames.7.minionsKilled': 0,
#  'participantFrames.7.participantId': 7,
#  'participantFrames.7.position.x': 14176,
#  'participantFrames.7.position.y': 14506,
#  'participantFrames.7.timeEnemySpentControlled': 0,
#  'participantFrames.7.totalGold': 500,
#  'participantFrames.7.xp': 0,
#  'participantFrames.8.championStats.abilityHaste': 0,
#  'participantFrames.8.championStats.abilityPower': 0,
#  'participantFrames.8.championStats.armor': 22,
#  'participantFrames.8.championStats.armorPen': 0,
#  'participantFrames.8.championStats.armorPenPercent': 0,
#  'participantFrames.8.championStats.attackDamage': 25,
#  'participantFrames.8.championStats.attackSpeed': 100,
#  'participantFrames.8.championStats.bonusArmorPenPercent': 0,
#  'participantFrames.8.championStats.bonusMagicPenPercent': 0,
#  'participantFrames.8.championStats.ccReduction': 0,
#  'participantFrames.8.championStats.cooldownReduction': 0,
#  'participantFrames.8.championStats.health': 526,
#  'participantFrames.8.championStats.healthMax': 526,
#  'participantFrames.8.championStats.healthRegen': 0,
#  'participantFrames.8.championStats.lifesteal': 0,
#  'participantFrames.8.championStats.magicPen': 0,
#  'participantFrames.8.championStats.magicPenPercent': 0,
#  'participantFrames.8.championStats.magicResist': 30,
#  'participantFrames.8.championStats.movementSpeed': 340,
#  'participantFrames.8.championStats.omnivamp': 0,
#  'participantFrames.8.championStats.physicalVamp': 0,
#  'participantFrames.8.championStats.power': 459,
#  'participantFrames.8.championStats.powerMax': 459,
#  'participantFrames.8.championStats.powerRegen': 0,
#  'participantFrames.8.championStats.spellVamp': 0,
#  'participantFrames.8.currentGold': 500,
#  'participantFrames.8.damageStats.magicDamageDone': 0,
#  'participantFrames.8.damageStats.magicDamageDoneToChampions': 0,
#  'participantFrames.8.damageStats.magicDamageTaken': 0,
#  'participantFrames.8.damageStats.physicalDamageDone': 0,
#  'participantFrames.8.damageStats.physicalDamageDoneToChampions': 0,
#  'participantFrames.8.damageStats.physicalDamageTaken': 0,
#  'participantFrames.8.damageStats.totalDamageDone': 0,
#  'participantFrames.8.damageStats.totalDamageDoneToChampions': 0,
#  'participantFrames.8.damageStats.totalDamageTaken': 0,
#  'participantFrames.8.damageStats.trueDamageDone': 0,
#  'participantFrames.8.damageStats.trueDamageDoneToChampions': 0,
#  'participantFrames.8.damageStats.trueDamageTaken': 0,
#  'participantFrames.8.goldPerSecond': 0,
#  'participantFrames.8.jungleMinionsKilled': 0,
#  'participantFrames.8.level': 1,
#  'participantFrames.8.minionsKilled': 0,
#  'participantFrames.8.participantId': 8,
#  'participantFrames.8.position.x': 14398,
#  'participantFrames.8.position.y': 14582,
#  'participantFrames.8.timeEnemySpentControlled': 0,
#  'participantFrames.8.totalGold': 500,
#  'participantFrames.8.xp': 0,
#  'participantFrames.9.championStats.abilityHaste': 0,
#  'participantFrames.9.championStats.abilityPower': 0,
#  'participantFrames.9.championStats.armor': 30,
#  'participantFrames.9.championStats.armorPen': 0,
#  'participantFrames.9.championStats.armorPenPercent': 0,
#  'participantFrames.9.championStats.attackDamage': 25,
#  'participantFrames.9.championStats.attackSpeed': 100,
#  'participantFrames.9.championStats.bonusArmorPenPercent': 0,
#  'participantFrames.9.championStats.bonusMagicPenPercent': 0,
#  'participantFrames.9.championStats.ccReduction': 0,
#  'participantFrames.9.championStats.cooldownReduction': 0,
#  'participantFrames.9.championStats.health': 490,
#  'participantFrames.9.championStats.healthMax': 490,
#  'participantFrames.9.championStats.healthRegen': 0,
#  'participantFrames.9.championStats.lifesteal': 0,
#  'participantFrames.9.championStats.magicPen': 0,
#  'participantFrames.9.championStats.magicPenPercent': 0,
#  'participantFrames.9.championStats.magicResist': 32,
#  'participantFrames.9.championStats.movementSpeed': 345,
#  'participantFrames.9.championStats.omnivamp': 0,
#  'participantFrames.9.championStats.physicalVamp': 0,
#  'participantFrames.9.championStats.power': 115,
#  'participantFrames.9.championStats.powerMax': 115,
#  'participantFrames.9.championStats.powerRegen': 0,
#  'participantFrames.9.championStats.spellVamp': 0,
#  'participantFrames.9.currentGold': 500,
#  'participantFrames.9.damageStats.magicDamageDone': 0,
#  'participantFrames.9.damageStats.magicDamageDoneToChampions': 0,
#  'participantFrames.9.damageStats.magicDamageTaken': 0,
#  'participantFrames.9.damageStats.physicalDamageDone': 0,
#  'participantFrames.9.damageStats.physicalDamageDoneToChampions': 0,
#  'participantFrames.9.damageStats.physicalDamageTaken': 0,
#  'participantFrames.9.damageStats.totalDamageDone': 0,
#  'participantFrames.9.damageStats.totalDamageDoneToChampions': 0,
#  'participantFrames.9.damageStats.totalDamageTaken': 0,
#  'participantFrames.9.damageStats.trueDamageDone': 0,
#  'participantFrames.9.damageStats.trueDamageDoneToChampions': 0,
#  'participantFrames.9.damageStats.trueDamageTaken': 0,
#  'participantFrames.9.goldPerSecond': 0,
#  'participantFrames.9.jungleMinionsKilled': 0,
#  'participantFrames.9.level': 1,
#  'participantFrames.9.minionsKilled': 0,
#  'participantFrames.9.participantId': 9,
#  'participantFrames.9.position.x': 14539,
#  'participantFrames.9.position.y': 14394,
#  'participantFrames.9.timeEnemySpentControlled': 0,
#  'participantFrames.9.totalGold': 500,
#  'participantFrames.9.xp': 0,
#  'participantFrames.10.championStats.abilityHaste': 0,
#  'participantFrames.10.championStats.abilityPower': 0,
#  'participantFrames.10.championStats.armor': 22,
#  'participantFrames.10.championStats.armorPen': 0,
#  'participantFrames.10.championStats.armorPenPercent': 0,
#  'participantFrames.10.championStats.attackDamage': 25,
#  'participantFrames.10.championStats.attackSpeed': 100,
#  'participantFrames.10.championStats.bonusArmorPenPercent': 0,
#  'participantFrames.10.championStats.bonusMagicPenPercent': 0,
#  'participantFrames.10.championStats.ccReduction': 0,
#  'participantFrames.10.championStats.cooldownReduction': 0,
#  'participantFrames.10.championStats.health': 520,
#  'participantFrames.10.championStats.healthMax': 520,
#  'participantFrames.10.championStats.healthRegen': 0,
#  'participantFrames.10.championStats.lifesteal': 0,
#  'participantFrames.10.championStats.magicPen': 0,
#  'participantFrames.10.championStats.magicPenPercent': 0,
#  'participantFrames.10.championStats.magicResist': 30,
#  'participantFrames.10.championStats.movementSpeed': 340,
#  'participantFrames.10.championStats.omnivamp': 0,
#  'participantFrames.10.championStats.physicalVamp': 0,
#  'participantFrames.10.championStats.power': 469,
#  'participantFrames.10.championStats.powerMax': 469,
#  'participantFrames.10.championStats.powerRegen': 0,
#  'participantFrames.10.championStats.spellVamp': 0,
#  'participantFrames.10.currentGold': 500,
#  'participantFrames.10.damageStats.magicDamageDone': 0,
#  'participantFrames.10.damageStats.magicDamageDoneToChampions': 0,
#  'participantFrames.10.damageStats.magicDamageTaken': 0,
#  'participantFrames.10.damageStats.physicalDamageDone': 0,
#  'participantFrames.10.damageStats.physicalDamageDoneToChampions': 0,
#  'participantFrames.10.damageStats.physicalDamageTaken': 0,
#  'participantFrames.10.damageStats.totalDamageDone': 0,
#  'participantFrames.10.damageStats.totalDamageDoneToChampions': 0,
#  'participantFrames.10.damageStats.totalDamageTaken': 0,
#  'participantFrames.10.damageStats.trueDamageDone': 0,
#  'participantFrames.10.damageStats.trueDamageDoneToChampions': 0,
#  'participantFrames.10.damageStats.trueDamageTaken': 0,
#  'participantFrames.10.goldPerSecond': 0,
#  'participantFrames.10.jungleMinionsKilled': 0,
#  'participantFrames.10.level': 1,
#  'participantFrames.10.minionsKilled': 0,
#  'participantFrames.10.participantId': 10,
#  'participantFrames.10.position.x': 14404,
#  'participantFrames.10.position.y': 14201,
#  'participantFrames.10.timeEnemySpentControlled': 0,
#  'participantFrames.10.totalGold': 500,
#  'participantFrames.10.xp': 0}

# %%
tier_list = ['PLATINUM', 'DIAMOND']
division_list = ['I', 'II', 'III', 'IV']
apis = 0
for tier in tier_list:
    for division in division_list:
        for page in range(1, 100000):
            now_user_list = get_user_list_from_tier(tier, division, page)
            apis += 1
            if len(now_user_list[0]) == 0:
                break
            for user in now_user_list[0]:
                puuid = user['summonerName']
                game_list = get_matches_from_puuid(puuid, 10)
                print(puuid)
                print(game_list)
                apis += 1
                for game in game_list[0]:
                    now_game = get_match_detail_from_game_id(game)
                    apis += 1
                    #print(now_game)
                    break
# Out:
# ERROR OCCURED 400
# Apsiod
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# Nxsty
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# 체리핑크 사나이
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# jug ovo
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# OAO283
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# Nangseul Fan
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# FriendIy
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# 도영잉
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# 느뀜이
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# 실수해도좋게봐줘
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# 기도의 신
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ERROR OCCURED 400
# jiaohuanyusheng
# ({'status': {'message': 'Bad Request - Exception decrypting nPixoDpQyq_omm9w-gDWhphxV3yeMwYZN0HC1M1mYWGaA7tvTVRFaUiDPw0GxhVWcqol5opvRFtd6Q', 'status_code': 400}}, 400)
# ERROR OCCURED 404
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\WINDOWS\TEMP/ipykernel_13016/2685967145.py in <module>
#      11             for user in now_user_list[0]:
#      12                 puuid = user['summonerName']
# ---> 13                 game_list = get_matches_from_puuid(puuid, 10)
#      14                 print(puuid)
#      15                 print(game_list)
#
# C:\WINDOWS\TEMP/ipykernel_13016/1467720980.py in get_matches_from_puuid(puuid, count)
#       9         "X-Riot-Token": token
#      10     }
# ---> 11     res = requests.get(url, headers=header)
#      12     if res.status_code != 200:
#      13         print("ERROR OCCURED", res.status_code)
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     409             context.load_default_certs()
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#     413             keyfile=self.key_file,
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     447
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#     451         )
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     491
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#     495         return ssl_context.wrap_socket(sock)
#
# ~\anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# ~\anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# ~\anaconda3\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:
